# %%
import os
import argparse

import torch

import rlcard

from rlcard.agents import DQNAgent, RandomAgent
from rlcard.utils import (
    get_device,
    set_seed,
    tournament,
    reorganize,
    Logger,
    plot_curve,
)

import numpy as np

# %%
# Initialize the Uno environment
env = rlcard.make('uno')

# %%
# The paths for saving the logs and learning curves
log_dir = './experiments/uno_dqn_result/'

# %%
agent = DQNAgent(
                 num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[64,64],
                 replay_memory_size=5000,
                 update_target_estimator_every=100,
                 epsilon_decay_steps=10000,
                 learning_rate=0.0005,
                 batch_size=32,
                 device=get_device(),
                 save_path=log_dir
                 )
# Out:
# --> Running on the CPU

# %%
# Set the number of players
num_players = 2

# Set the players in the environment
env.set_agents([agent] + [RandomAgent(env.num_actions) for _ in range(num_players - 1)])

# Reset the environment
state = env.reset()

# %% [markdown]
# ## Training the Agent
# To train the agent, you will need to create a training loop. During each iteration of the loop, the agent makes a decision, the environment is updated, and the agent learns from the result.

# %%
def adjust_rewards(trajectories, payoffs):
    adjusted_trajectories = []
    for traj in trajectories:
        adjusted_traj = []
        for state, action, reward, next_state, done in traj:
            if action == 60:  # draw a card
                reward -= 1  # Penalty for drawing a card
                
            # Add more conditions for other strategic rewards
            # increment reward for actions 0-9, play red cards
            elif action >= 0 and action <= 9:
                reward += 1
            # increment reward for actions 15-24, play green cards
            elif action >= 15 and action <= 24:
                reward += 1
            # increment reward for actions 30-39, play blue cards
            elif action >= 30 and action <= 39:
                reward += 1
            # increment reward for actions 45-54, play yellow cards
            elif action >= 45 and action <= 54:
                reward += 1
                        
            
            adjusted_traj.append((state, action, reward, next_state, done))
        adjusted_trajectories.append(adjusted_traj)
    return adjusted_trajectories

# %% [markdown]
# # Building out the simulation
#
# Previously, the code would run an entire/complete simulation. However, this restricts the ability to learn from moves within the simulation.

# %%
episode_num = 50000  # Number of episodes 

evaluate_every = 1000 # Evaluate the agent every X episodes
evaluate_num = 100  # Number of games played in evaluation

with Logger(log_dir) as logger:
    for episode in range(episode_num):  # Number of episodes

        trajectories, payoffs = env.run(is_training=True)

        # Assuming 'payoffs' are the game outcomes for each player
        for i, payoff in enumerate(payoffs):
            if payoff > 0:  # Assuming a positive payoff means winning
                payoffs[i] = 100
            else:
                payoffs[i] = -25

        trajectories = reorganize(trajectories, payoffs)

        # After reorganizing the trajectories, adjust the rewards
        trajectories = adjust_rewards(trajectories, payoffs)
        # print(trajectories[0])

        for ts in trajectories[0]:
            agent.feed(ts)
        
        if episode % evaluate_every == 0:
                logger.log_performance(
                    episode,
                    tournament(
                        env,
                        evaluate_num,
                    )[0]
                )

    # Get the paths
    csv_path, fig_path = logger.csv_path, logger.fig_path
# Out:
# ----------------------------------------
#   episode      |  0
#   reward       |  -0.08
# ----------------------------------------
# INFO - Step 100, rl-loss: 1.6680594682693481
# INFO - Copied model parameters to target network.
# INFO - Step 200, rl-loss: 17.9861392974853556
# INFO - Copied model parameters to target network.
# INFO - Step 300, rl-loss: 298.746276855468755
# INFO - Copied model parameters to target network.
# INFO - Step 400, rl-loss: 655.47613525390622
# INFO - Copied model parameters to target network.
# INFO - Step 500, rl-loss: 585.06903076171885
# INFO - Copied model parameters to target network.
# INFO - Step 600, rl-loss: 543.44512939453123
# INFO - Copied model parameters to target network.
# INFO - Step 700, rl-loss: 281.84103393554691
# INFO - Copied model parameters to target network.
# INFO - Step 800, rl-loss: 269.70611572265625
# INFO - Copied model parameters to target network.
# INFO - Step 900, rl-loss: 280.49554443359375
# INFO - Copied model parameters to target network.
# INFO - Step 1000, rl-loss: 4.910082817077637
# INFO - Copied model parameters to target network.
# INFO - Step 1100, rl-loss: 527.45568847656255
# INFO - Copied model parameters to target network.
# INFO - Step 1200, rl-loss: 17.252372741699223
# INFO - Copied model parameters to target network.
# INFO - Step 1300, rl-loss: 5.3620257377624515
# INFO - Copied model parameters to target network.
# INFO - Step 1400, rl-loss: 5.8925867080688483
# INFO - Copied model parameters to target network.
# INFO - Step 1500, rl-loss: 275.60101318359375
# INFO - Copied model parameters to target network.
# INFO - Step 1600, rl-loss: 271.65270996093755
# INFO - Copied model parameters to target network.
# INFO - Step 1700, rl-loss: 6.2013826370239265
# INFO - Copied model parameters to target network.
# INFO - Step 1800, rl-loss: 9.2396574020385748
# INFO - Copied model parameters to target network.
# INFO - Step 1900, rl-loss: 8.1724777221679695
# INFO - Copied model parameters to target network.
# INFO - Step 2000, rl-loss: 8.1084928512573246
# INFO - Copied model parameters to target network.
# INFO - Step 2100, rl-loss: 550.44287109375484
# INFO - Copied model parameters to target network.
# INFO - Step 2200, rl-loss: 15.108042716979985
# INFO - Copied model parameters to target network.
# INFO - Step 2300, rl-loss: 18.752258300781255
# INFO - Copied model parameters to target network.
# INFO - Step 2400, rl-loss: 254.48452758789062
# INFO - Copied model parameters to target network.
# INFO - Step 2500, rl-loss: 672.96728515625324
# INFO - Copied model parameters to target network.
# INFO - Step 2600, rl-loss: 22.164682388305664
# INFO - Copied model parameters to target network.
# INFO - Step 2700, rl-loss: 736.88964843751875
# INFO - Copied model parameters to target network.
# INFO - Step 2800, rl-loss: 470.02362060546875
# INFO - Copied model parameters to target network.
# INFO - Step 2900, rl-loss: 29.513944625854492
# INFO - Copied model parameters to target network.
# INFO - Step 3000, rl-loss: 35.622558593754062
# INFO - Copied model parameters to target network.
# INFO - Step 3100, rl-loss: 644.09338378906256
# INFO - Copied model parameters to target network.
# INFO - Step 3200, rl-loss: 51.301292419433594
# INFO - Copied model parameters to target network.
# INFO - Step 3300, rl-loss: 241.66712951660156
# INFO - Copied model parameters to target network.
# INFO - Step 3400, rl-loss: 27.013023376464844
# INFO - Copied model parameters to target network.
# INFO - Step 3500, rl-loss: 199.49095153808594
# INFO - Copied model parameters to target network.
# INFO - Step 3600, rl-loss: 212.28903198242188
# INFO - Copied model parameters to target network.
# INFO - Step 3700, rl-loss: 27.099973678588867
# INFO - Copied model parameters to target network.
# INFO - Step 3800, rl-loss: 229.96626281738286
# INFO - Copied model parameters to target network.
# INFO - Step 3900, rl-loss: 20.479290008544922
# INFO - Copied model parameters to target network.
# INFO - Step 4000, rl-loss: 218.66909790039062
# INFO - Copied model parameters to target network.
# INFO - Step 4100, rl-loss: 204.40132141113287
# INFO - Copied model parameters to target network.
# INFO - Step 4200, rl-loss: 237.21897888183594
# INFO - Copied model parameters to target network.
# INFO - Step 4300, rl-loss: 292.74707031250862
# INFO - Copied model parameters to target network.
# INFO - Step 4400, rl-loss: 88.043899536132815
# INFO - Copied model parameters to target network.
# INFO - Step 4500, rl-loss: 36.851413726806645
# INFO - Copied model parameters to target network.
# INFO - Step 4600, rl-loss: 40.590118408203125
# INFO - Copied model parameters to target network.
# INFO - Step 4700, rl-loss: 24.654773712158203
# INFO - Copied model parameters to target network.
# INFO - Step 4800, rl-loss: 23.924060821533203
# INFO - Copied model parameters to target network.
# INFO - Step 4900, rl-loss: 247.60890197753906
# INFO - Copied model parameters to target network.
# INFO - Step 5000, rl-loss: 257.78067016601566
# INFO - Copied model parameters to target network.
# INFO - Step 5100, rl-loss: 38.597000122070315
# INFO - Copied model parameters to target network.
# INFO - Step 5200, rl-loss: 62.057010650634766
# INFO - Copied model parameters to target network.
# INFO - Step 5300, rl-loss: 37.347576141357425
# INFO - Copied model parameters to target network.
# INFO - Step 5400, rl-loss: 237.61056518554688
# INFO - Copied model parameters to target network.
# INFO - Step 5500, rl-loss: 420.80145263671875
# INFO - Copied model parameters to target network.
# INFO - Step 5600, rl-loss: 27.148767471313477
# INFO - Copied model parameters to target network.
# INFO - Step 5700, rl-loss: 43.357063293457036
# INFO - Copied model parameters to target network.
# INFO - Step 5800, rl-loss: 173.65710449218756
# INFO - Copied model parameters to target network.
# INFO - Step 5900, rl-loss: 549.00592041015622
# INFO - Copied model parameters to target network.
# INFO - Step 6000, rl-loss: 32.172054290771484
# INFO - Copied model parameters to target network.
# INFO - Step 6100, rl-loss: 30.035499572753906
# INFO - Copied model parameters to target network.
# INFO - Step 6200, rl-loss: 26.135776519775395
# INFO - Copied model parameters to target network.
# INFO - Step 6300, rl-loss: 20.735206604003906
# INFO - Copied model parameters to target network.
# INFO - Step 6400, rl-loss: 415.04357910156256
# INFO - Copied model parameters to target network.
# INFO - Step 6500, rl-loss: 226.81472778320312
# INFO - Copied model parameters to target network.
# INFO - Step 6600, rl-loss: 12.930165290832523
# INFO - Copied model parameters to target network.
# INFO - Step 6700, rl-loss: 87.167396545410164
# INFO - Copied model parameters to target network.
# INFO - Step 6800, rl-loss: 208.98181152343756
# INFO - Copied model parameters to target network.
# INFO - Step 6900, rl-loss: 54.651973724365234
# INFO - Copied model parameters to target network.
# INFO - Step 7000, rl-loss: 420.03967285156255
# INFO - Copied model parameters to target network.
# INFO - Step 7100, rl-loss: 22.556007385253906
# INFO - Copied model parameters to target network.
# INFO - Step 7200, rl-loss: 229.32220458984375
# INFO - Copied model parameters to target network.
# INFO - Step 7300, rl-loss: 40.870319366455086
# INFO - Copied model parameters to target network.
# INFO - Step 7400, rl-loss: 257.35659790039064
# INFO - Copied model parameters to target network.
# INFO - Step 7500, rl-loss: 412.60202026367195
# INFO - Copied model parameters to target network.
# INFO - Step 7600, rl-loss: 57.443733215332032
# INFO - Copied model parameters to target network.
# INFO - Step 7700, rl-loss: 169.47415161132812
# INFO - Copied model parameters to target network.
# INFO - Step 7800, rl-loss: 133.89848327636725
# INFO - Copied model parameters to target network.
# INFO - Step 7900, rl-loss: 601.28338623046886
# INFO - Copied model parameters to target network.
# INFO - Step 8000, rl-loss: 206.20486450195312
# INFO - Copied model parameters to target network.
# INFO - Step 8100, rl-loss: 29.480356216430664
# INFO - Copied model parameters to target network.
# INFO - Step 8200, rl-loss: 74.585411071777342
# INFO - Copied model parameters to target network.
# INFO - Step 8300, rl-loss: 32.543121337890625
# INFO - Copied model parameters to target network.
# INFO - Step 8400, rl-loss: 73.334274291992194
# INFO - Copied model parameters to target network.
# INFO - Step 8500, rl-loss: 40.736133575439456
# INFO - Copied model parameters to target network.
# INFO - Step 8600, rl-loss: 243.29483032226562
# INFO - Copied model parameters to target network.
# INFO - Step 8700, rl-loss: 226.60853576660156
# INFO - Copied model parameters to target network.
# INFO - Step 8800, rl-loss: 237.02265930175785
# INFO - Copied model parameters to target network.
# INFO - Step 8900, rl-loss: 50.701019287109375
# INFO - Copied model parameters to target network.
# INFO - Step 9000, rl-loss: 244.87045288085938
# INFO - Copied model parameters to target network.
# INFO - Step 9100, rl-loss: 199.59268188476562
# INFO - Copied model parameters to target network.
# INFO - Step 9200, rl-loss: 26.705764770507812
# INFO - Copied model parameters to target network.
# INFO - Step 9300, rl-loss: 579.22436523437538
# INFO - Copied model parameters to target network.
# INFO - Step 9400, rl-loss: 45.277557373046875
# INFO - Copied model parameters to target network.
# INFO - Step 9500, rl-loss: 131.68359375574225
# INFO - Copied model parameters to target network.
# INFO - Step 9600, rl-loss: 303.93838500976562
# INFO - Copied model parameters to target network.
# INFO - Step 9700, rl-loss: 181.23139953613287
# INFO - Copied model parameters to target network.
# INFO - Step 9800, rl-loss: 182.66931152343752
# INFO - Copied model parameters to target network.
# INFO - Step 9900, rl-loss: 28.151088714599616
# INFO - Copied model parameters to target network.
# INFO - Step 10000, rl-loss: 681.5025024414062
# INFO - Copied model parameters to target network.
# INFO - Step 10100, rl-loss: 326.71295166015625
# INFO - Copied model parameters to target network.
# INFO - Step 10200, rl-loss: 105.87306213378906
# INFO - Copied model parameters to target network.
# INFO - Step 10300, rl-loss: 232.45404052734375
# INFO - Copied model parameters to target network.
# INFO - Step 10400, rl-loss: 81.400382995605472
# INFO - Copied model parameters to target network.
# INFO - Step 10500, rl-loss: 276.17736816406254
# INFO - Copied model parameters to target network.
# INFO - Step 10600, rl-loss: 148.65170288085938
# INFO - Copied model parameters to target network.
# INFO - Step 10700, rl-loss: 43.457305908203125
# INFO - Copied model parameters to target network.
# INFO - Step 10800, rl-loss: 206.82934570312594
# INFO - Copied model parameters to target network.
# INFO - Step 10900, rl-loss: 76.288520812988285
# INFO - Copied model parameters to target network.
# INFO - Step 11000, rl-loss: 35.700027465820316
# INFO - Copied model parameters to target network.
# INFO - Step 11100, rl-loss: 295.73635864257815
# INFO - Copied model parameters to target network.
# INFO - Step 11200, rl-loss: 27.044395446777344
# INFO - Copied model parameters to target network.
# INFO - Step 11300, rl-loss: 91.117156982421882
# INFO - Copied model parameters to target network.
# INFO - Step 11400, rl-loss: 118.72604370117188
# INFO - Copied model parameters to target network.
# INFO - Step 11500, rl-loss: 227.19531251953125
# INFO - Copied model parameters to target network.
# INFO - Step 11600, rl-loss: 34.808624267578125
# INFO - Copied model parameters to target network.
# INFO - Step 11700, rl-loss: 52.039871215820313
# INFO - Copied model parameters to target network.
# INFO - Step 11800, rl-loss: 82.505630493164062
# INFO - Copied model parameters to target network.
# INFO - Step 11900, rl-loss: 45.861793518066406
# INFO - Copied model parameters to target network.
# INFO - Step 12000, rl-loss: 179.20880126953125
# INFO - Copied model parameters to target network.
# INFO - Step 12100, rl-loss: 144.63598632812525
# INFO - Copied model parameters to target network.
# INFO - Step 12200, rl-loss: 45.487491607666016
# INFO - Copied model parameters to target network.
# INFO - Step 12300, rl-loss: 163.61657714843756
# INFO - Copied model parameters to target network.
# INFO - Step 12400, rl-loss: 224.04765319824225
# INFO - Copied model parameters to target network.
# INFO - Step 12500, rl-loss: 37.660896301269535
# INFO - Copied model parameters to target network.
# INFO - Step 12600, rl-loss: 229.94676208496094
# INFO - Copied model parameters to target network.
# INFO - Step 12700, rl-loss: 109.67193603515625
# INFO - Copied model parameters to target network.
# INFO - Step 12800, rl-loss: 93.507156372070316
# INFO - Copied model parameters to target network.
# INFO - Step 12900, rl-loss: 330.73052978515625
# INFO - Copied model parameters to target network.
# INFO - Step 13000, rl-loss: 72.541145324707034
# INFO - Copied model parameters to target network.
# INFO - Step 13100, rl-loss: 157.93904113769535
# INFO - Copied model parameters to target network.
# INFO - Step 13200, rl-loss: 33.757644653320312
# INFO - Copied model parameters to target network.
# INFO - Step 13300, rl-loss: 49.509841918945314
# INFO - Copied model parameters to target network.
# INFO - Step 13400, rl-loss: 431.23907470703125
# INFO - Copied model parameters to target network.
# INFO - Step 13500, rl-loss: 222.18205261230478
# INFO - Copied model parameters to target network.
# INFO - Step 13600, rl-loss: 222.45271301269532
# INFO - Copied model parameters to target network.
# INFO - Step 13700, rl-loss: 349.23962402343758
# INFO - Copied model parameters to target network.
# INFO - Step 13800, rl-loss: 211.52510070800785
# INFO - Copied model parameters to target network.
# INFO - Step 13900, rl-loss: 464.54895019531254
# INFO - Copied model parameters to target network.
# INFO - Step 14000, rl-loss: 61.111534118652344
# INFO - Copied model parameters to target network.
# INFO - Step 14100, rl-loss: 219.07257080078125
# INFO - Copied model parameters to target network.
# INFO - Step 14200, rl-loss: 44.229148864746094
# INFO - Copied model parameters to target network.
# INFO - Step 14300, rl-loss: 161.62719726562552
# INFO - Copied model parameters to target network.
# INFO - Step 14400, rl-loss: 157.31578063964844
# INFO - Copied model parameters to target network.
# INFO - Step 14500, rl-loss: 225.42160034179688
# INFO - Copied model parameters to target network.
# INFO - Step 14600, rl-loss: 91.845046997070315
# INFO - Copied model parameters to target network.
# INFO - Step 14700, rl-loss: 41.614112854003906
# INFO - Copied model parameters to target network.
# INFO - Step 14800, rl-loss: 293.03933715820316
# INFO - Copied model parameters to target network.
# INFO - Step 14900, rl-loss: 117.16697692871094
# INFO - Copied model parameters to target network.
# INFO - Step 15000, rl-loss: 167.67352294921875
# INFO - Copied model parameters to target network.
# INFO - Step 15100, rl-loss: 165.45469665527344
# INFO - Copied model parameters to target network.
# INFO - Step 15200, rl-loss: 101.86235809326172
# INFO - Copied model parameters to target network.
# INFO - Step 15300, rl-loss: 160.01510620117188
# INFO - Copied model parameters to target network.
# INFO - Step 15400, rl-loss: 226.92782592773438
# INFO - Copied model parameters to target network.
# INFO - Step 15500, rl-loss: 47.676506042480478
# INFO - Copied model parameters to target network.
# INFO - Step 15600, rl-loss: 68.817993164062538
# INFO - Copied model parameters to target network.
# INFO - Step 15700, rl-loss: 89.493041992187578
# INFO - Copied model parameters to target network.
# INFO - Step 15800, rl-loss: 143.33819580078125
# INFO - Copied model parameters to target network.
# INFO - Step 15900, rl-loss: 55.090328216552734
# INFO - Copied model parameters to target network.
# INFO - Step 16000, rl-loss: 147.70845031738287
# INFO - Copied model parameters to target network.
# INFO - Step 16100, rl-loss: 104.09472656250156
# INFO - Copied model parameters to target network.
# INFO - Step 16200, rl-loss: 222.70887756347656
# INFO - Copied model parameters to target network.
# INFO - Step 16300, rl-loss: 29.402858734130862
# INFO - Copied model parameters to target network.
# INFO - Step 16400, rl-loss: 49.573513031005866
# INFO - Copied model parameters to target network.
# INFO - Step 16500, rl-loss: 75.116104125976565
# INFO - Copied model parameters to target network.
# INFO - Step 16600, rl-loss: 151.15473937988284
# INFO - Copied model parameters to target network.
# INFO - Step 16700, rl-loss: 289.36703491210942
# INFO - Copied model parameters to target network.
# INFO - Step 16800, rl-loss: 266.02795410156258
# INFO - Copied model parameters to target network.
# INFO - Step 16900, rl-loss: 127.27502441406254
# INFO - Copied model parameters to target network.
# INFO - Step 17000, rl-loss: 254.67794799804688
# INFO - Copied model parameters to target network.
# INFO - Step 17100, rl-loss: 47.375701904296875
# INFO - Copied model parameters to target network.
# INFO - Step 17200, rl-loss: 234.65219116210938
# INFO - Copied model parameters to target network.
# INFO - Step 17300, rl-loss: 102.86980438232422
# INFO - Copied model parameters to target network.
# INFO - Step 17400, rl-loss: 98.682373046875529
# INFO - Copied model parameters to target network.
# INFO - Step 17500, rl-loss: 168.67105102539062
# INFO - Copied model parameters to target network.
# INFO - Step 17600, rl-loss: 93.348342895507818
# INFO - Copied model parameters to target network.
# INFO - Step 17700, rl-loss: 153.31001281738285
# INFO - Copied model parameters to target network.
# INFO - Step 17800, rl-loss: 195.57530212402344
# INFO - Copied model parameters to target network.
# INFO - Step 17900, rl-loss: 175.09202575683594
# INFO - Copied model parameters to target network.
# INFO - Step 18000, rl-loss: 102.60276031494144
# INFO - Copied model parameters to target network.
# INFO - Step 18100, rl-loss: 125.67289733886719
# INFO - Copied model parameters to target network.
# INFO - Step 18200, rl-loss: 44.002830505371094
# INFO - Copied model parameters to target network.
# INFO - Step 18300, rl-loss: 102.05491638183594
# INFO - Copied model parameters to target network.
# INFO - Step 18400, rl-loss: 146.17443847656254
# INFO - Copied model parameters to target network.
# INFO - Step 18500, rl-loss: 189.20242309570312
# INFO - Copied model parameters to target network.
# INFO - Step 18600, rl-loss: 100.41374206542969
# INFO - Copied model parameters to target network.
# INFO - Step 18700, rl-loss: 137.75875854492188
# INFO - Copied model parameters to target network.
# INFO - Step 18800, rl-loss: 88.989250183105474
# INFO - Copied model parameters to target network.
# INFO - Step 18900, rl-loss: 103.42449188232422
# INFO - Copied model parameters to target network.
# INFO - Step 19000, rl-loss: 153.02609252929688
# INFO - Copied model parameters to target network.
# INFO - Step 19100, rl-loss: 156.44187927246094
# INFO - Copied model parameters to target network.
# INFO - Step 19200, rl-loss: 181.02445983886722
# INFO - Copied model parameters to target network.
# INFO - Step 19300, rl-loss: 221.24201965332036
# INFO - Copied model parameters to target network.
# INFO - Step 19400, rl-loss: 95.111808776855478
# INFO - Copied model parameters to target network.
# INFO - Step 19500, rl-loss: 40.525821685791016
# INFO - Copied model parameters to target network.
# INFO - Step 19600, rl-loss: 49.243480682373054
# INFO - Copied model parameters to target network.
# INFO - Step 19700, rl-loss: 165.20816040039062
# INFO - Copied model parameters to target network.
# INFO - Step 19800, rl-loss: 29.592334747314453
# INFO - Copied model parameters to target network.
# INFO - Step 19900, rl-loss: 222.61322021484375
# INFO - Copied model parameters to target network.
# INFO - Step 20000, rl-loss: 289.43582153320314
# INFO - Copied model parameters to target network.
# INFO - Step 20100, rl-loss: 244.72824096679688
# INFO - Copied model parameters to target network.
# INFO - Step 20200, rl-loss: 104.50810241699219
# INFO - Copied model parameters to target network.
# INFO - Step 20300, rl-loss: 239.53279113769535
# INFO - Copied model parameters to target network.
# INFO - Step 20400, rl-loss: 188.91740417480478
# INFO - Copied model parameters to target network.
# INFO - Step 20500, rl-loss: 164.18229675292975
# INFO - Copied model parameters to target network.
# INFO - Step 20600, rl-loss: 201.00946044921875
# INFO - Copied model parameters to target network.
# INFO - Step 20700, rl-loss: 125.74816131591797
# INFO - Copied model parameters to target network.
# INFO - Step 20800, rl-loss: 83.698043823242192
# INFO - Copied model parameters to target network.
# INFO - Step 20900, rl-loss: 302.73425292968752
# INFO - Copied model parameters to target network.
# INFO - Step 21000, rl-loss: 135.14677429199224
# INFO - Copied model parameters to target network.
# INFO - Step 21100, rl-loss: 69.283477783203125
# INFO - Copied model parameters to target network.
# INFO - Step 21200, rl-loss: 286.97973632812556
# INFO - Copied model parameters to target network.
# INFO - Step 21300, rl-loss: 76.054138183593756
# INFO - Copied model parameters to target network.
# INFO - Step 21400, rl-loss: 188.56195068359375
# INFO - Copied model parameters to target network.
# INFO - Step 21500, rl-loss: 62.078247070312512
# INFO - Copied model parameters to target network.
# INFO - Step 21600, rl-loss: 95.541313171386724
# INFO - Copied model parameters to target network.
# INFO - Step 21700, rl-loss: 204.10469055175783
# INFO - Copied model parameters to target network.
# INFO - Step 21800, rl-loss: 168.77893066406258
# INFO - Copied model parameters to target network.
# INFO - Step 21900, rl-loss: 101.47146606445312
# INFO - Copied model parameters to target network.
# INFO - Step 22000, rl-loss: 280.45208740234375
# INFO - Copied model parameters to target network.
# INFO - Step 22100, rl-loss: 40.504703521728516
# INFO - Copied model parameters to target network.
# INFO - Step 22200, rl-loss: 61.813503265380865
# INFO - Copied model parameters to target network.
# INFO - Step 22300, rl-loss: 132.78588867187595
# INFO - Copied model parameters to target network.
# INFO - Step 22400, rl-loss: 132.53987121582039
# INFO - Copied model parameters to target network.
# INFO - Step 22500, rl-loss: 70.172447204589848
# INFO - Copied model parameters to target network.
# INFO - Step 22600, rl-loss: 390.25311279296875
# INFO - Copied model parameters to target network.
# INFO - Step 22700, rl-loss: 193.50595092773438
# INFO - Copied model parameters to target network.
# INFO - Step 22800, rl-loss: 75.144355773925788
# INFO - Copied model parameters to target network.
# INFO - Step 22900, rl-loss: 184.83876037597656
# INFO - Copied model parameters to target network.
# INFO - Step 23000, rl-loss: 118.42985534667969
# INFO - Copied model parameters to target network.
# INFO - Step 23100, rl-loss: 187.96530151367188
# INFO - Copied model parameters to target network.
# INFO - Step 23200, rl-loss: 74.463363647460948
# INFO - Copied model parameters to target network.
# INFO - Step 23300, rl-loss: 132.40748596191406
# INFO - Copied model parameters to target network.
# INFO - Step 23400, rl-loss: 174.23057556152344
# INFO - Copied model parameters to target network.
# INFO - Step 23500, rl-loss: 257.16564941406252
# INFO - Copied model parameters to target network.
# INFO - Step 23600, rl-loss: 107.61744689941406
# INFO - Copied model parameters to target network.
# INFO - Step 23700, rl-loss: 160.40652465820312
# INFO - Copied model parameters to target network.
# INFO - Step 23800, rl-loss: 34.329498291015625
# INFO - Copied model parameters to target network.
# INFO - Step 23859, rl-loss: 161.59486389160156
# ----------------------------------------
#   episode      |  1000
#   reward       |  0.14
# ----------------------------------------
# INFO - Step 23900, rl-loss: 125.29295349121094
# INFO - Copied model parameters to target network.
# INFO - Step 24000, rl-loss: 32.770668029785156
# INFO - Copied model parameters to target network.
# INFO - Step 24100, rl-loss: 107.40614318847656
# INFO - Copied model parameters to target network.
# INFO - Step 24200, rl-loss: 114.39817810058594
# INFO - Copied model parameters to target network.
# INFO - Step 24300, rl-loss: 237.03561401367188
# INFO - Copied model parameters to target network.
# INFO - Step 24400, rl-loss: 175.80967712402344
# INFO - Copied model parameters to target network.
# INFO - Step 24500, rl-loss: 109.02884674072266
# INFO - Copied model parameters to target network.
# INFO - Step 24600, rl-loss: 82.329895019531254
# INFO - Copied model parameters to target network.
# INFO - Step 24700, rl-loss: 240.70422363281258
# INFO - Copied model parameters to target network.
# INFO - Step 24800, rl-loss: 29.601835250854492
# INFO - Copied model parameters to target network.
# INFO - Step 24900, rl-loss: 144.35652160644532
# INFO - Copied model parameters to target network.
# INFO - Step 25000, rl-loss: 192.31648254394534
# INFO - Copied model parameters to target network.
# INFO - Step 25100, rl-loss: 147.50491333007812
# INFO - Copied model parameters to target network.
# INFO - Step 25200, rl-loss: 118.14567565917969
# INFO - Copied model parameters to target network.
# INFO - Step 25300, rl-loss: 76.945991516113286
# INFO - Copied model parameters to target network.
# INFO - Step 25400, rl-loss: 264.58944702148445
# INFO - Copied model parameters to target network.
# INFO - Step 25500, rl-loss: 145.41557312011728
# INFO - Copied model parameters to target network.
# INFO - Step 25600, rl-loss: 76.843780517578128
# INFO - Copied model parameters to target network.
# INFO - Step 25700, rl-loss: 178.90708923339844
# INFO - Copied model parameters to target network.
# INFO - Step 25800, rl-loss: 237.29705810546875
# INFO - Copied model parameters to target network.
# INFO - Step 25900, rl-loss: 94.930305480957038
# INFO - Copied model parameters to target network.
# INFO - Step 26000, rl-loss: 122.47155761718755
# INFO - Copied model parameters to target network.
# INFO - Step 26100, rl-loss: 193.44125366210938
# INFO - Copied model parameters to target network.
# INFO - Step 26200, rl-loss: 55.715591430664067
# INFO - Copied model parameters to target network.
# INFO - Step 26300, rl-loss: 84.537956237792978
# INFO - Copied model parameters to target network.
# INFO - Step 26400, rl-loss: 103.11967468261719
# INFO - Copied model parameters to target network.
# INFO - Step 26500, rl-loss: 44.717899322509766
# INFO - Copied model parameters to target network.
# INFO - Step 26600, rl-loss: 206.17529296875756
# INFO - Copied model parameters to target network.
# INFO - Step 26700, rl-loss: 140.44473266601562
# INFO - Copied model parameters to target network.
# INFO - Step 26800, rl-loss: 226.38653564453125
# INFO - Copied model parameters to target network.
# INFO - Step 26900, rl-loss: 205.52140808105478
# INFO - Copied model parameters to target network.
# INFO - Step 27000, rl-loss: 108.57190704345703
# INFO - Copied model parameters to target network.
# INFO - Step 27100, rl-loss: 248.75378417968758
# INFO - Copied model parameters to target network.
# INFO - Step 27200, rl-loss: 269.88867187576566
# INFO - Copied model parameters to target network.
# INFO - Step 27300, rl-loss: 233.33781433105476
# INFO - Copied model parameters to target network.
# INFO - Step 27400, rl-loss: 110.05789184570312
# INFO - Copied model parameters to target network.
# INFO - Step 27500, rl-loss: 89.532348632812586
# INFO - Copied model parameters to target network.
# INFO - Step 27600, rl-loss: 213.39050292968755
# INFO - Copied model parameters to target network.
# INFO - Step 27700, rl-loss: 108.00336456298828
# INFO - Copied model parameters to target network.
# INFO - Step 27800, rl-loss: 184.90481567382812
# INFO - Copied model parameters to target network.
# INFO - Step 27900, rl-loss: 178.28865051269536
# INFO - Copied model parameters to target network.
# INFO - Step 28000, rl-loss: 221.15176391601562
# INFO - Copied model parameters to target network.
# INFO - Step 28100, rl-loss: 143.81758117675782
# INFO - Copied model parameters to target network.
# INFO - Step 28200, rl-loss: 236.99713134765625
# INFO - Copied model parameters to target network.
# INFO - Step 28300, rl-loss: 51.054588317871094
# INFO - Copied model parameters to target network.
# INFO - Step 28400, rl-loss: 124.47489166259766
# INFO - Copied model parameters to target network.
# INFO - Step 28500, rl-loss: 59.760429382324224
# INFO - Copied model parameters to target network.
# INFO - Step 28600, rl-loss: 83.997718811035165
# INFO - Copied model parameters to target network.
# INFO - Step 28700, rl-loss: 38.078552246093758
# INFO - Copied model parameters to target network.
# INFO - Step 28800, rl-loss: 91.423583984375348
# INFO - Copied model parameters to target network.
# INFO - Step 28900, rl-loss: 65.788520812988286
# INFO - Copied model parameters to target network.
# INFO - Step 29000, rl-loss: 70.701339721679694
# INFO - Copied model parameters to target network.
# INFO - Step 29100, rl-loss: 158.84252929687514
# INFO - Copied model parameters to target network.
# INFO - Step 29200, rl-loss: 85.752960205078125
# INFO - Copied model parameters to target network.
# INFO - Step 29300, rl-loss: 93.843688964843756
# INFO - Copied model parameters to target network.
# INFO - Step 29400, rl-loss: 288.68063354492197
# INFO - Copied model parameters to target network.
# INFO - Step 29500, rl-loss: 57.626106262207036
# INFO - Copied model parameters to target network.
# INFO - Step 29600, rl-loss: 215.85365295410156
# INFO - Copied model parameters to target network.
# INFO - Step 29700, rl-loss: 255.74749755859375
# INFO - Copied model parameters to target network.
# INFO - Step 29800, rl-loss: 130.59350585937578
# INFO - Copied model parameters to target network.
# INFO - Step 29900, rl-loss: 54.899150848388672
# INFO - Copied model parameters to target network.
# INFO - Step 30000, rl-loss: 101.43540954589844
# INFO - Copied model parameters to target network.
# INFO - Step 30100, rl-loss: 64.196823120117194
# INFO - Copied model parameters to target network.
# INFO - Step 30200, rl-loss: 209.19876098632812
# INFO - Copied model parameters to target network.
# INFO - Step 30300, rl-loss: 131.41113281257525
# INFO - Copied model parameters to target network.
# INFO - Step 30400, rl-loss: 257.55957031259228
# INFO - Copied model parameters to target network.
# INFO - Step 30500, rl-loss: 179.38804626464844
# INFO - Copied model parameters to target network.
# INFO - Step 30600, rl-loss: 89.542495727539068
# INFO - Copied model parameters to target network.
# INFO - Step 30700, rl-loss: 57.857612609863284
# INFO - Copied model parameters to target network.
# INFO - Step 30800, rl-loss: 148.75592041015625
# INFO - Copied model parameters to target network.
# INFO - Step 30900, rl-loss: 169.53337097167978
# INFO - Copied model parameters to target network.
# INFO - Step 31000, rl-loss: 58.548416137695312
# INFO - Copied model parameters to target network.
# INFO - Step 31100, rl-loss: 387.92083740234375
# INFO - Copied model parameters to target network.
# INFO - Step 31200, rl-loss: 125.63510894775392
# INFO - Copied model parameters to target network.
# INFO - Step 31300, rl-loss: 122.92241668701172
# INFO - Copied model parameters to target network.
# INFO - Step 31400, rl-loss: 196.32054138183594
# INFO - Copied model parameters to target network.
# INFO - Step 31500, rl-loss: 158.76173400878906
# INFO - Copied model parameters to target network.
# INFO - Step 31600, rl-loss: 136.29742431640625
# INFO - Copied model parameters to target network.
# INFO - Step 31700, rl-loss: 171.37553405761728
# INFO - Copied model parameters to target network.
# INFO - Step 31800, rl-loss: 146.04837036132812
# INFO - Copied model parameters to target network.
# INFO - Step 31900, rl-loss: 134.27426147460938
# INFO - Copied model parameters to target network.
# INFO - Step 32000, rl-loss: 146.59191894531252
# INFO - Copied model parameters to target network.
# INFO - Step 32100, rl-loss: 141.88984680175788
# INFO - Copied model parameters to target network.
# INFO - Step 32200, rl-loss: 87.111923217773445
# INFO - Copied model parameters to target network.
# INFO - Step 32300, rl-loss: 181.58171081542974
# INFO - Copied model parameters to target network.
# INFO - Step 32400, rl-loss: 413.25549316406255
# INFO - Copied model parameters to target network.
# INFO - Step 32500, rl-loss: 195.99774169921875
# INFO - Copied model parameters to target network.
# INFO - Step 32600, rl-loss: 226.06604003906259
# INFO - Copied model parameters to target network.
# INFO - Step 32700, rl-loss: 334.76452636718758
# INFO - Copied model parameters to target network.
# INFO - Step 32800, rl-loss: 104.46637725830078
# INFO - Copied model parameters to target network.
# INFO - Step 32900, rl-loss: 159.53030395507812
# INFO - Copied model parameters to target network.
# INFO - Step 33000, rl-loss: 221.93849182128906
# INFO - Copied model parameters to target network.
# INFO - Step 33100, rl-loss: 179.77439880371094
# INFO - Copied model parameters to target network.
# INFO - Step 33200, rl-loss: 258.24334716796875
# INFO - Copied model parameters to target network.
# INFO - Step 33300, rl-loss: 226.50085449218752
# INFO - Copied model parameters to target network.
# INFO - Step 33400, rl-loss: 127.11433410644531
# INFO - Copied model parameters to target network.
# INFO - Step 33500, rl-loss: 153.42144775390625
# INFO - Copied model parameters to target network.
# INFO - Step 33600, rl-loss: 114.95851898193365
# INFO - Copied model parameters to target network.
# INFO - Step 33700, rl-loss: 170.25808715820312
# INFO - Copied model parameters to target network.
# INFO - Step 33800, rl-loss: 207.70268249511725
# INFO - Copied model parameters to target network.
# INFO - Step 33900, rl-loss: 177.58119201660156
# INFO - Copied model parameters to target network.
# INFO - Step 34000, rl-loss: 114.93495941162116
# INFO - Copied model parameters to target network.
# INFO - Step 34100, rl-loss: 82.787864685058606
# INFO - Copied model parameters to target network.
# INFO - Step 34200, rl-loss: 114.99632263183594
# INFO - Copied model parameters to target network.
# INFO - Step 34300, rl-loss: 309.70767211914065
# INFO - Copied model parameters to target network.
# INFO - Step 34400, rl-loss: 70.345970153808692
# INFO - Copied model parameters to target network.
# INFO - Step 34500, rl-loss: 283.39001464843752
# INFO - Copied model parameters to target network.
# INFO - Step 34600, rl-loss: 68.171638488769534
# INFO - Copied model parameters to target network.
# INFO - Step 34700, rl-loss: 118.89164733886719
# INFO - Copied model parameters to target network.
# INFO - Step 34800, rl-loss: 144.68006896972656
# INFO - Copied model parameters to target network.
# INFO - Step 34900, rl-loss: 239.57380676269538
# INFO - Copied model parameters to target network.
# INFO - Step 35000, rl-loss: 152.86601257324222
# INFO - Copied model parameters to target network.
# INFO - Step 35100, rl-loss: 157.30940246582035
# INFO - Copied model parameters to target network.
# INFO - Step 35200, rl-loss: 230.79733276367188
# INFO - Copied model parameters to target network.
# INFO - Step 35300, rl-loss: 185.01741027832032
# INFO - Copied model parameters to target network.
# INFO - Step 35400, rl-loss: 149.24511718750547
# INFO - Copied model parameters to target network.
# INFO - Step 35500, rl-loss: 150.25634765625656
# INFO - Copied model parameters to target network.
# INFO - Step 35600, rl-loss: 345.86108398437525
# INFO - Copied model parameters to target network.
# INFO - Step 35700, rl-loss: 108.72969818115234
# INFO - Copied model parameters to target network.
# INFO - Step 35800, rl-loss: 189.46295166015625
# INFO - Copied model parameters to target network.
# INFO - Step 35900, rl-loss: 296.38870239257814
# INFO - Copied model parameters to target network.
# INFO - Step 36000, rl-loss: 140.33567810058594
# INFO - Copied model parameters to target network.
# INFO - Step 36100, rl-loss: 62.504257202148445
# INFO - Copied model parameters to target network.
# INFO - Step 36200, rl-loss: 146.47073364257812
# INFO - Copied model parameters to target network.
# INFO - Step 36300, rl-loss: 56.993450164794925
# INFO - Copied model parameters to target network.
# INFO - Step 36400, rl-loss: 207.13914489746094
# INFO - Copied model parameters to target network.
# INFO - Step 36500, rl-loss: 157.55009460449228
# INFO - Copied model parameters to target network.
# INFO - Step 36600, rl-loss: 126.41979980468755
# INFO - Copied model parameters to target network.
# INFO - Step 36700, rl-loss: 81.354164123535168
# INFO - Copied model parameters to target network.
# INFO - Step 36800, rl-loss: 154.91616821289062
# INFO - Copied model parameters to target network.
# INFO - Step 36900, rl-loss: 130.52499389648438
# INFO - Copied model parameters to target network.
# INFO - Step 37000, rl-loss: 94.774009704589848
# INFO - Copied model parameters to target network.
# INFO - Step 37100, rl-loss: 220.65127563476562
# INFO - Copied model parameters to target network.
# INFO - Step 37200, rl-loss: 201.09678649902344
# INFO - Copied model parameters to target network.
# INFO - Step 37300, rl-loss: 152.23507690429688
# INFO - Copied model parameters to target network.
# INFO - Step 37400, rl-loss: 187.23184204101562
# INFO - Copied model parameters to target network.
# INFO - Step 37500, rl-loss: 134.47399902343758
# INFO - Copied model parameters to target network.
# INFO - Step 37600, rl-loss: 182.58920288085938
# INFO - Copied model parameters to target network.
# INFO - Step 37700, rl-loss: 133.57786560058594
# INFO - Copied model parameters to target network.
# INFO - Step 37800, rl-loss: 73.969062805175785
# INFO - Copied model parameters to target network.
# INFO - Step 37900, rl-loss: 95.418037414550786
# INFO - Copied model parameters to target network.
# INFO - Step 38000, rl-loss: 187.45202636718752
# INFO - Copied model parameters to target network.
# INFO - Step 38100, rl-loss: 262.77026367187552
# INFO - Copied model parameters to target network.
# INFO - Step 38200, rl-loss: 118.20635223388672
# INFO - Copied model parameters to target network.
# INFO - Step 38300, rl-loss: 145.28480529785156
# INFO - Copied model parameters to target network.
# INFO - Step 38400, rl-loss: 185.01400756835938
# INFO - Copied model parameters to target network.
# INFO - Step 38500, rl-loss: 163.00526428222656
# INFO - Copied model parameters to target network.
# INFO - Step 38600, rl-loss: 201.83206176757812
# INFO - Copied model parameters to target network.
# INFO - Step 38700, rl-loss: 238.16522216796875
# INFO - Copied model parameters to target network.
# INFO - Step 38800, rl-loss: 214.53250122070312
# INFO - Copied model parameters to target network.
# INFO - Step 38900, rl-loss: 103.06441497802734
# INFO - Copied model parameters to target network.
# INFO - Step 39000, rl-loss: 130.40405273437592
# INFO - Copied model parameters to target network.
# INFO - Step 39100, rl-loss: 207.17829895019538
# INFO - Copied model parameters to target network.
# INFO - Step 39200, rl-loss: 226.58456420898438
# INFO - Copied model parameters to target network.
# INFO - Step 39300, rl-loss: 171.45060729980478
# INFO - Copied model parameters to target network.
# INFO - Step 39400, rl-loss: 63.574859619140625
# INFO - Copied model parameters to target network.
# INFO - Step 39500, rl-loss: 114.73193359375594
# INFO - Copied model parameters to target network.
# INFO - Step 39600, rl-loss: 75.590911865234389
# INFO - Copied model parameters to target network.
# INFO - Step 39700, rl-loss: 352.05096435546875
# INFO - Copied model parameters to target network.
# INFO - Step 39800, rl-loss: 152.72666931152344
# INFO - Copied model parameters to target network.
# INFO - Step 39900, rl-loss: 182.58515930175782
# INFO - Copied model parameters to target network.
# INFO - Step 40000, rl-loss: 85.842918395996156
# INFO - Copied model parameters to target network.
# INFO - Step 40100, rl-loss: 284.76007080078125
# INFO - Copied model parameters to target network.
# INFO - Step 40200, rl-loss: 168.14646911621094
# INFO - Copied model parameters to target network.
# INFO - Step 40300, rl-loss: 85.801452636718755
# INFO - Copied model parameters to target network.
# INFO - Step 40400, rl-loss: 144.49198913574225
# INFO - Copied model parameters to target network.
# INFO - Step 40500, rl-loss: 392.36013793945317
# INFO - Copied model parameters to target network.
# INFO - Step 40600, rl-loss: 114.88015747070312
# INFO - Copied model parameters to target network.
# INFO - Step 40700, rl-loss: 88.313064575195315
# INFO - Copied model parameters to target network.
# INFO - Step 40800, rl-loss: 230.14134216308594
# INFO - Copied model parameters to target network.
# INFO - Step 40900, rl-loss: 266.87915039062595
# INFO - Copied model parameters to target network.
# INFO - Step 41000, rl-loss: 136.98762512207032
# INFO - Copied model parameters to target network.
# INFO - Step 41100, rl-loss: 165.98225402832038
# INFO - Copied model parameters to target network.
# INFO - Step 41200, rl-loss: 232.44200134277344
# INFO - Copied model parameters to target network.
# INFO - Step 41300, rl-loss: 75.881423950195315
# INFO - Copied model parameters to target network.
# INFO - Step 41400, rl-loss: 145.23658752441406
# INFO - Copied model parameters to target network.
# INFO - Step 41500, rl-loss: 148.78311157226562
# INFO - Copied model parameters to target network.
# INFO - Step 41600, rl-loss: 119.39260864257812
# INFO - Copied model parameters to target network.
# INFO - Step 41700, rl-loss: 238.70436096191406
# INFO - Copied model parameters to target network.
# INFO - Step 41800, rl-loss: 327.32965087890625
# INFO - Copied model parameters to target network.
# INFO - Step 41900, rl-loss: 202.29418945312558
# INFO - Copied model parameters to target network.
# INFO - Step 42000, rl-loss: 220.68656921386725
# INFO - Copied model parameters to target network.
# INFO - Step 42100, rl-loss: 259.60421752929694
# INFO - Copied model parameters to target network.
# INFO - Step 42200, rl-loss: 268.02221679687581
# INFO - Copied model parameters to target network.
# INFO - Step 42300, rl-loss: 160.85508728027344
# INFO - Copied model parameters to target network.
# INFO - Step 42400, rl-loss: 194.23367309570312
# INFO - Copied model parameters to target network.
# INFO - Step 42500, rl-loss: 183.14550781259688
# INFO - Copied model parameters to target network.
# INFO - Step 42600, rl-loss: 133.07974243164062
# INFO - Copied model parameters to target network.
# INFO - Step 42700, rl-loss: 375.87554931640625
# INFO - Copied model parameters to target network.
# INFO - Step 42800, rl-loss: 220.42156982421875
# INFO - Copied model parameters to target network.
# INFO - Step 42900, rl-loss: 300.62451171875752
# INFO - Copied model parameters to target network.
# INFO - Step 43000, rl-loss: 180.95236206054688
# INFO - Copied model parameters to target network.
# INFO - Step 43100, rl-loss: 158.70442199707034
# INFO - Copied model parameters to target network.
# INFO - Step 43200, rl-loss: 137.14909362792974
# INFO - Copied model parameters to target network.
# INFO - Step 43300, rl-loss: 352.29702758789065
# INFO - Copied model parameters to target network.
# INFO - Step 43400, rl-loss: 152.00285339355476
# INFO - Copied model parameters to target network.
# INFO - Step 43500, rl-loss: 234.97279357910156
# INFO - Copied model parameters to target network.
# INFO - Step 43600, rl-loss: 162.96966552734375
# INFO - Copied model parameters to target network.
# INFO - Step 43700, rl-loss: 262.20428466796875
# INFO - Copied model parameters to target network.
# INFO - Step 43800, rl-loss: 96.875793457031254
# INFO - Copied model parameters to target network.
# INFO - Step 43900, rl-loss: 141.69761657714844
# INFO - Copied model parameters to target network.
# INFO - Step 44000, rl-loss: 150.72460937568756
# INFO - Copied model parameters to target network.
# INFO - Step 44100, rl-loss: 155.60578918457036
# INFO - Copied model parameters to target network.
# INFO - Step 44200, rl-loss: 137.59915161132812
# INFO - Copied model parameters to target network.
# INFO - Step 44300, rl-loss: 218.65716552734375
# INFO - Copied model parameters to target network.
# INFO - Step 44400, rl-loss: 183.35319519042974
# INFO - Copied model parameters to target network.
# INFO - Step 44500, rl-loss: 314.01611328125844
# INFO - Copied model parameters to target network.
# INFO - Step 44600, rl-loss: 128.96371459960938
# INFO - Copied model parameters to target network.
# INFO - Step 44700, rl-loss: 77.797492980957035
# INFO - Copied model parameters to target network.
# INFO - Step 44800, rl-loss: 132.07661437988287
# INFO - Copied model parameters to target network.
# INFO - Step 44900, rl-loss: 162.46850585937575
# INFO - Copied model parameters to target network.
# INFO - Step 45000, rl-loss: 108.56231689453125
# INFO - Copied model parameters to target network.
# INFO - Step 45100, rl-loss: 214.73847961425782
# INFO - Copied model parameters to target network.
# INFO - Step 45200, rl-loss: 119.81520080566406
# INFO - Copied model parameters to target network.
# INFO - Step 45300, rl-loss: 461.41683959960942
# INFO - Copied model parameters to target network.
# INFO - Step 45400, rl-loss: 190.05404663085938
# INFO - Copied model parameters to target network.
# INFO - Step 45500, rl-loss: 277.38513183593756
# INFO - Copied model parameters to target network.
# INFO - Step 45600, rl-loss: 255.90426635742188
# INFO - Copied model parameters to target network.
# INFO - Step 45700, rl-loss: 366.06579589843752
# INFO - Copied model parameters to target network.
# INFO - Step 45746, rl-loss: 137.27923583984375
# ----------------------------------------
#   episode      |  2000
#   reward       |  -0.06
# ----------------------------------------
# INFO - Step 45800, rl-loss: 188.06536865234375
# INFO - Copied model parameters to target network.
# INFO - Step 45900, rl-loss: 182.60420227050788
# INFO - Copied model parameters to target network.
# INFO - Step 46000, rl-loss: 139.37623596191406
# INFO - Copied model parameters to target network.
# INFO - Step 46100, rl-loss: 256.20486450195318
# INFO - Copied model parameters to target network.
# INFO - Step 46200, rl-loss: 77.051536560058696
# INFO - Copied model parameters to target network.
# INFO - Step 46300, rl-loss: 239.69491577148438
# INFO - Copied model parameters to target network.
# INFO - Step 46400, rl-loss: 83.077087402343758
# INFO - Copied model parameters to target network.
# INFO - Step 46500, rl-loss: 420.48193359375719
# INFO - Copied model parameters to target network.
# INFO - Step 46600, rl-loss: 193.53950500488288
# INFO - Copied model parameters to target network.
# INFO - Step 46700, rl-loss: 82.111305236816462
# INFO - Copied model parameters to target network.
# INFO - Step 46800, rl-loss: 170.88911437988288
# INFO - Copied model parameters to target network.
# INFO - Step 46900, rl-loss: 317.46676635742194
# INFO - Copied model parameters to target network.
# INFO - Step 47000, rl-loss: 112.15482330322266
# INFO - Copied model parameters to target network.
# INFO - Step 47100, rl-loss: 247.48446655273438
# INFO - Copied model parameters to target network.
# INFO - Step 47200, rl-loss: 135.59259033203125
# INFO - Copied model parameters to target network.
# INFO - Step 47300, rl-loss: 197.91343688964844
# INFO - Copied model parameters to target network.
# INFO - Step 47400, rl-loss: 125.79359436035156
# INFO - Copied model parameters to target network.
# INFO - Step 47500, rl-loss: 169.59619140625562
# INFO - Copied model parameters to target network.
# INFO - Step 47600, rl-loss: 119.51277923583984
# INFO - Copied model parameters to target network.
# INFO - Step 47700, rl-loss: 66.631980895996106
# INFO - Copied model parameters to target network.
# INFO - Step 47800, rl-loss: 48.306133270263675
# INFO - Copied model parameters to target network.
# INFO - Step 47900, rl-loss: 123.92020416259766
# INFO - Copied model parameters to target network.
# INFO - Step 48000, rl-loss: 92.135704040527342
# INFO - Copied model parameters to target network.
# INFO - Step 48100, rl-loss: 102.06504821777344
# INFO - Copied model parameters to target network.
# INFO - Step 48200, rl-loss: 274.46514892578125
# INFO - Copied model parameters to target network.
# INFO - Step 48300, rl-loss: 278.34909057617192
# INFO - Copied model parameters to target network.
# INFO - Step 48400, rl-loss: 94.710113525390625
# INFO - Copied model parameters to target network.
# INFO - Step 48500, rl-loss: 132.24461364746094
# INFO - Copied model parameters to target network.
# INFO - Step 48600, rl-loss: 119.38883209228516
# INFO - Copied model parameters to target network.
# INFO - Step 48700, rl-loss: 232.84277343754062
# INFO - Copied model parameters to target network.
# INFO - Step 48800, rl-loss: 154.67420959472656
# INFO - Copied model parameters to target network.
# INFO - Step 48900, rl-loss: 91.398834228515625
# INFO - Copied model parameters to target network.
# INFO - Step 49000, rl-loss: 261.13659667968755
# INFO - Copied model parameters to target network.
# INFO - Step 49100, rl-loss: 120.40666198730469
# INFO - Copied model parameters to target network.
# ...
# INFO - Step 212000, rl-loss: 150.69931030273438
# INFO - Copied model parameters to target network.
# INFO - Step 212100, rl-loss: 162.82083129882812
# INFO - Copied model parameters to target network.
# INFO - Step 212200, rl-loss: 232.37792968753438
# INFO - Copied model parameters to target network.
# INFO - Step 212300, rl-loss: 271.81777954101569
# INFO - Copied model parameters to target network.
# INFO - Step 212400, rl-loss: 161.48709106445312
# INFO - Copied model parameters to target network.
# INFO - Step 212500, rl-loss: 375.64590454101565
# INFO - Copied model parameters to target network.
# INFO - Step 212600, rl-loss: 110.28892517089844
# INFO - Copied model parameters to target network.
# INFO - Step 212700, rl-loss: 167.29721069335938
# INFO - Copied model parameters to target network.
# INFO - Step 212800, rl-loss: 245.89707946777344
# INFO - Copied model parameters to target network.
# INFO - Step 212900, rl-loss: 362.85131835937538
# INFO - Copied model parameters to target network.
# INFO - Step 213000, rl-loss: 136.66766357421875
# INFO - Copied model parameters to target network.
# INFO - Step 213100, rl-loss: 426.22052001953125
# INFO - Copied model parameters to target network.
# INFO - Step 213200, rl-loss: 90.551811218261728
# INFO - Copied model parameters to target network.
# INFO - Step 213300, rl-loss: 278.81610107421875
# INFO - Copied model parameters to target network.
# INFO - Step 213400, rl-loss: 85.568389892578125
# INFO - Copied model parameters to target network.
# INFO - Step 213500, rl-loss: 119.97874450683594
# INFO - Copied model parameters to target network.
# INFO - Step 213600, rl-loss: 208.42630004882812
# INFO - Copied model parameters to target network.
# INFO - Step 213700, rl-loss: 209.56459045410156
# INFO - Copied model parameters to target network.
# INFO - Step 213800, rl-loss: 288.50198364257818
# INFO - Copied model parameters to target network.
# INFO - Step 213900, rl-loss: 285.72872924804695
# INFO - Copied model parameters to target network.
# INFO - Step 214000, rl-loss: 169.16954040527344
# INFO - Copied model parameters to target network.
# INFO - Step 214100, rl-loss: 184.02047729492188
# INFO - Copied model parameters to target network.
# INFO - Step 214200, rl-loss: 149.58132934570312
# INFO - Copied model parameters to target network.
# INFO - Step 214300, rl-loss: 199.63880920410156
# INFO - Copied model parameters to target network.
# INFO - Step 214400, rl-loss: 97.957359313964844
# INFO - Copied model parameters to target network.
# INFO - Step 214500, rl-loss: 259.34783935546875
# INFO - Copied model parameters to target network.
# INFO - Step 214600, rl-loss: 261.33532714843758
# INFO - Copied model parameters to target network.
# INFO - Step 214700, rl-loss: 106.75779724121094
# INFO - Copied model parameters to target network.
# INFO - Step 214800, rl-loss: 95.504409790039064
# INFO - Copied model parameters to target network.
# INFO - Step 214900, rl-loss: 248.11495971679688
# INFO - Copied model parameters to target network.
# INFO - Step 215000, rl-loss: 245.98260498046875
# INFO - Copied model parameters to target network.
# INFO - Step 215100, rl-loss: 195.92735290527344
# INFO - Copied model parameters to target network.
# INFO - Step 215200, rl-loss: 67.825004577636728
# INFO - Copied model parameters to target network.
# INFO - Step 215300, rl-loss: 110.92933654785156
# INFO - Copied model parameters to target network.
# INFO - Step 215400, rl-loss: 152.76982116699225
# INFO - Copied model parameters to target network.
# INFO - Step 215500, rl-loss: 202.76348876953125
# INFO - Copied model parameters to target network.
# INFO - Step 215600, rl-loss: 117.76843261718755
# INFO - Copied model parameters to target network.
# INFO - Step 215700, rl-loss: 215.44067382812556
# INFO - Copied model parameters to target network.
# INFO - Step 215800, rl-loss: 398.73486328125375
# INFO - Copied model parameters to target network.
# INFO - Step 215900, rl-loss: 160.76466369628906
# INFO - Copied model parameters to target network.
# INFO - Step 216000, rl-loss: 290.43362426757815
# INFO - Copied model parameters to target network.
# INFO - Step 216100, rl-loss: 87.329528808593754
# INFO - Copied model parameters to target network.
# INFO - Step 216200, rl-loss: 289.10235595703125
# INFO - Copied model parameters to target network.
# INFO - Step 216300, rl-loss: 408.96478271484375
# INFO - Copied model parameters to target network.
# INFO - Step 216400, rl-loss: 82.448135375976569
# INFO - Copied model parameters to target network.
# INFO - Step 216500, rl-loss: 277.44735717773446
# INFO - Copied model parameters to target network.
# INFO - Step 216600, rl-loss: 101.44953155517578
# INFO - Copied model parameters to target network.
# INFO - Step 216700, rl-loss: 247.82960510253906
# INFO - Copied model parameters to target network.
# INFO - Step 216800, rl-loss: 170.12690734863286
# INFO - Copied model parameters to target network.
# INFO - Step 216900, rl-loss: 90.948265075683675
# INFO - Copied model parameters to target network.
# INFO - Step 217000, rl-loss: 166.75555419921875
# INFO - Copied model parameters to target network.
# INFO - Step 217100, rl-loss: 144.38008117675784
# INFO - Copied model parameters to target network.
# INFO - Step 217200, rl-loss: 130.74374389648438
# INFO - Copied model parameters to target network.
# INFO - Step 217300, rl-loss: 161.41838073730475
# INFO - Copied model parameters to target network.
# INFO - Step 217400, rl-loss: 165.76043701171875
# INFO - Copied model parameters to target network.
# INFO - Step 217500, rl-loss: 66.677375793457034
# INFO - Copied model parameters to target network.
# INFO - Step 217600, rl-loss: 120.07378387451172
# INFO - Copied model parameters to target network.
# INFO - Step 217700, rl-loss: 190.93438720703125
# INFO - Copied model parameters to target network.
# INFO - Step 217800, rl-loss: 172.58967590332035
# INFO - Copied model parameters to target network.
# INFO - Step 217900, rl-loss: 646.08026123046888
# INFO - Copied model parameters to target network.
# INFO - Step 218000, rl-loss: 314.85168457031252
# INFO - Copied model parameters to target network.
# INFO - Step 218100, rl-loss: 58.815975189208984
# INFO - Copied model parameters to target network.
# INFO - Step 218200, rl-loss: 70.568222045898448
# INFO - Copied model parameters to target network.
# INFO - Step 218300, rl-loss: 254.87878417968755
# INFO - Copied model parameters to target network.
# INFO - Step 218400, rl-loss: 216.67144775390625
# INFO - Copied model parameters to target network.
# INFO - Step 218500, rl-loss: 81.653251647949225
# INFO - Copied model parameters to target network.
# INFO - Step 218600, rl-loss: 118.60646057128906
# INFO - Copied model parameters to target network.
# INFO - Step 218700, rl-loss: 291.58105468751562
# INFO - Copied model parameters to target network.
# INFO - Step 218800, rl-loss: 314.07424926757816
# INFO - Copied model parameters to target network.
# INFO - Step 218900, rl-loss: 536.77252197265628
# INFO - Copied model parameters to target network.
# INFO - Step 219000, rl-loss: 146.98350524902344
# INFO - Copied model parameters to target network.
# INFO - Step 219100, rl-loss: 135.87167358398438
# INFO - Copied model parameters to target network.
# INFO - Step 219200, rl-loss: 111.16339874267578
# INFO - Copied model parameters to target network.
# INFO - Step 219300, rl-loss: 237.97718811035156
# INFO - Copied model parameters to target network.
# INFO - Step 219400, rl-loss: 109.10557556152344
# INFO - Copied model parameters to target network.
# INFO - Step 219500, rl-loss: 99.389587402343752
# INFO - Copied model parameters to target network.
# INFO - Step 219600, rl-loss: 288.12847900390625
# INFO - Copied model parameters to target network.
# INFO - Step 219700, rl-loss: 327.38497924804695
# INFO - Copied model parameters to target network.
# INFO - Step 219800, rl-loss: 475.06845092773442
# INFO - Copied model parameters to target network.
# INFO - Step 219900, rl-loss: 82.716072082519536
# INFO - Copied model parameters to target network.
# INFO - Step 220000, rl-loss: 213.85775756835938
# INFO - Copied model parameters to target network.
# INFO - Step 220100, rl-loss: 202.66076660156255
# INFO - Copied model parameters to target network.
# INFO - Step 220200, rl-loss: 129.58770751953125
# INFO - Copied model parameters to target network.
# INFO - Step 220300, rl-loss: 245.63835144042974
# INFO - Copied model parameters to target network.
# INFO - Step 220400, rl-loss: 36.332981109619146
# INFO - Copied model parameters to target network.
# INFO - Step 220500, rl-loss: 69.055305480957035
# INFO - Copied model parameters to target network.
# INFO - Step 220600, rl-loss: 225.17826843261724
# INFO - Copied model parameters to target network.
# INFO - Step 220700, rl-loss: 189.30281066894535
# INFO - Copied model parameters to target network.
# INFO - Step 220800, rl-loss: 163.53115844726562
# INFO - Copied model parameters to target network.
# INFO - Step 220900, rl-loss: 212.09791564941406
# INFO - Copied model parameters to target network.
# INFO - Step 221000, rl-loss: 156.28222656255476
# INFO - Copied model parameters to target network.
# INFO - Step 221100, rl-loss: 135.41828918457035
# INFO - Copied model parameters to target network.
# INFO - Step 221200, rl-loss: 298.77722167968755
# INFO - Copied model parameters to target network.
# INFO - Step 221300, rl-loss: 481.55331420898448
# INFO - Copied model parameters to target network.
# INFO - Step 221400, rl-loss: 144.04048156738289
# INFO - Copied model parameters to target network.
# INFO - Step 221500, rl-loss: 262.05819702148441
# INFO - Copied model parameters to target network.
# INFO - Step 221600, rl-loss: 90.335914611816475
# INFO - Copied model parameters to target network.
# INFO - Step 221700, rl-loss: 251.51779174804688
# INFO - Copied model parameters to target network.
# INFO - Step 221800, rl-loss: 298.94305419921875
# INFO - Copied model parameters to target network.
# INFO - Step 221900, rl-loss: 148.19226074218755
# INFO - Copied model parameters to target network.
# INFO - Step 222000, rl-loss: 66.477020263671885
# INFO - Copied model parameters to target network.
# INFO - Step 222100, rl-loss: 150.79698181152344
# INFO - Copied model parameters to target network.
# INFO - Step 222200, rl-loss: 128.41043090820312
# INFO - Copied model parameters to target network.
# INFO - Step 222300, rl-loss: 276.61260986328125
# INFO - Copied model parameters to target network.
# INFO - Step 222400, rl-loss: 84.551200866699225
# INFO - Copied model parameters to target network.
# INFO - Step 222500, rl-loss: 288.32327270507815
# INFO - Copied model parameters to target network.
# INFO - Step 222600, rl-loss: 249.54171752929688
# INFO - Copied model parameters to target network.
# INFO - Step 222700, rl-loss: 226.75689697265625
# INFO - Copied model parameters to target network.
# INFO - Step 222800, rl-loss: 190.32167053222656
# INFO - Copied model parameters to target network.
# INFO - Step 222900, rl-loss: 279.69012451171875
# INFO - Copied model parameters to target network.
# INFO - Step 223000, rl-loss: 182.87632751464844
# INFO - Copied model parameters to target network.
# INFO - Step 223100, rl-loss: 161.49119567871094
# INFO - Copied model parameters to target network.
# INFO - Step 223200, rl-loss: 250.17716979980472
# INFO - Copied model parameters to target network.
# INFO - Step 223300, rl-loss: 444.59628295898448
# INFO - Copied model parameters to target network.
# INFO - Step 223400, rl-loss: 198.30812072753906
# INFO - Copied model parameters to target network.
# INFO - Step 223500, rl-loss: 227.23629760742188
# INFO - Copied model parameters to target network.
# INFO - Step 223600, rl-loss: 109.98517608642578
# INFO - Copied model parameters to target network.
# INFO - Step 223700, rl-loss: 207.32823181152344
# INFO - Copied model parameters to target network.
# INFO - Step 223800, rl-loss: 68.047515869140625
# INFO - Copied model parameters to target network.
# INFO - Step 223900, rl-loss: 382.47991943359375
# INFO - Copied model parameters to target network.
# INFO - Step 224000, rl-loss: 319.59777832031258
# INFO - Copied model parameters to target network.
# INFO - Step 224100, rl-loss: 158.95324707031251
# INFO - Copied model parameters to target network.
# INFO - Step 224200, rl-loss: 145.13194274902344
# INFO - Copied model parameters to target network.
# INFO - Step 224300, rl-loss: 258.23559570312515
# INFO - Copied model parameters to target network.
# INFO - Step 224400, rl-loss: 213.22113037109375
# INFO - Copied model parameters to target network.
# INFO - Step 224500, rl-loss: 215.61791992187555
# INFO - Copied model parameters to target network.
# INFO - Step 224600, rl-loss: 190.08958435058594
# INFO - Copied model parameters to target network.
# INFO - Step 224700, rl-loss: 87.536918640136726
# INFO - Copied model parameters to target network.
# INFO - Step 224800, rl-loss: 211.33187866210938
# INFO - Copied model parameters to target network.
# INFO - Step 224900, rl-loss: 529.06280517578126
# INFO - Copied model parameters to target network.
# INFO - Step 225000, rl-loss: 276.91784667968755
# INFO - Copied model parameters to target network.
# INFO - Step 225100, rl-loss: 176.88526916503906
# INFO - Copied model parameters to target network.
# INFO - Step 225200, rl-loss: 252.97106933593754
# INFO - Copied model parameters to target network.
# INFO - Step 225300, rl-loss: 173.37767028808594
# INFO - Copied model parameters to target network.
# INFO - Step 225400, rl-loss: 173.93392944335938
# INFO - Copied model parameters to target network.
# INFO - Step 225500, rl-loss: 246.36384582519534
# INFO - Copied model parameters to target network.
# INFO - Step 225600, rl-loss: 262.86102294921875
# INFO - Copied model parameters to target network.
# INFO - Step 225700, rl-loss: 101.16246795654297
# INFO - Copied model parameters to target network.
# INFO - Step 225800, rl-loss: 175.36125183105474
# INFO - Copied model parameters to target network.
# INFO - Step 225900, rl-loss: 262.78421020507812
# INFO - Copied model parameters to target network.
# INFO - Step 226000, rl-loss: 203.19898986816406
# INFO - Copied model parameters to target network.
# INFO - Step 226100, rl-loss: 146.74975585937588
# INFO - Copied model parameters to target network.
# INFO - Step 226200, rl-loss: 216.33825683593754
# INFO - Copied model parameters to target network.
# INFO - Step 226300, rl-loss: 354.99990844726562
# INFO - Copied model parameters to target network.
# INFO - Step 226400, rl-loss: 293.69161987304694
# INFO - Copied model parameters to target network.
# INFO - Step 226500, rl-loss: 262.46948242187594
# INFO - Copied model parameters to target network.
# INFO - Step 226600, rl-loss: 339.58288574218756
# INFO - Copied model parameters to target network.
# INFO - Step 226700, rl-loss: 199.51606750488285
# INFO - Copied model parameters to target network.
# INFO - Step 226800, rl-loss: 167.05429077148438
# INFO - Copied model parameters to target network.
# INFO - Step 226900, rl-loss: 138.08671569824227
# INFO - Copied model parameters to target network.
# INFO - Step 227000, rl-loss: 267.23977661132814
# INFO - Copied model parameters to target network.
# INFO - Step 227100, rl-loss: 201.76416015625062
# INFO - Copied model parameters to target network.
# INFO - Step 227200, rl-loss: 200.46685791015625
# INFO - Copied model parameters to target network.
# INFO - Step 227300, rl-loss: 167.52609252929688
# INFO - Copied model parameters to target network.
# INFO - Step 227400, rl-loss: 246.31561279296875
# INFO - Copied model parameters to target network.
# INFO - Step 227500, rl-loss: 293.76324462890625
# INFO - Copied model parameters to target network.
# INFO - Step 227600, rl-loss: 237.67599487304688
# INFO - Copied model parameters to target network.
# INFO - Step 227700, rl-loss: 146.59616088867188
# INFO - Copied model parameters to target network.
# INFO - Step 227800, rl-loss: 194.31854248046875
# INFO - Copied model parameters to target network.
# INFO - Step 227900, rl-loss: 279.42309570312516
# INFO - Copied model parameters to target network.
# INFO - Step 228000, rl-loss: 134.78604125976562
# INFO - Copied model parameters to target network.
# INFO - Step 228100, rl-loss: 120.53809356689453
# INFO - Copied model parameters to target network.
# INFO - Step 228193, rl-loss: 315.74032592773445
# Logs saved in ./experiments/uno_dqn_result/

# %% [markdown]
# ## Evaluating the Agent
# After training, evaluate your agent's performance. You can use RLCard's tournament function to play the game multiple times and see how well your agent performs:

# %%
# Plot the learning curve
plot_curve(csv_path, fig_path, "dqn")

# Save model
save_path = os.path.join(log_dir, 'model.pth')
torch.save(agent, save_path)
print('Model saved in', save_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plot the learning curve
# ----> 2 plot_curve(csv_path, fig_path, "dqn")
#       4 # Save model
#       5 save_path = os.path.join(log_dir, 'model.pth')
#
# NameError: name 'plot_curve' is not defined
