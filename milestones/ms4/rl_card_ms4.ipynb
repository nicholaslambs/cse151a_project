# %%
import os
import argparse

import torch

import rlcard

from rlcard.agents import DQNAgent, RandomAgent
from rlcard.utils import (
    get_device,
    set_seed,
    tournament,
    reorganize,
    Logger,
    plot_curve,
)

import numpy as np

# %%
# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 3060 Ti

# %%
# Initialize the Uno environment
env = rlcard.make('uno')

# %%
# The paths for saving the logs and learning curves
log_dir = './experiments/uno_dqn_result/'

# %%
agent = DQNAgent(
                 num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[64,64],
                 replay_memory_size=5000,
                 update_target_estimator_every=100,
                 epsilon_decay_steps=10000,
                 learning_rate=0.0005,
                 batch_size=32,
                 device=device,
                 save_path=log_dir,
                 )

# %%
# Set the number of players
num_players = 2

# Set the players in the environment
env.set_agents([agent] + [RandomAgent(env.num_actions) for _ in range(num_players - 1)])

# Reset the environment
state = env.reset()

# %% [markdown]
# ## Training the Agent
# To train the agent, you will need to create a training loop. During each iteration of the loop, the agent makes a decision, the environment is updated, and the agent learns from the result.

# %%
# Reward function for static moves on action cards, playing and drawing cards
def adjust_rewards(trajectories, payoffs):
    adjusted_trajectories = []
    for traj in trajectories:
        adjusted_traj = []
        for state, action, reward, next_state, done in traj:
            if action == 60:  # Draw a card
                reward -= 1  # Penalty for drawing a card

            elif action >= 0 and action <= 9:  # Red number cards
                reward += 1
            elif action >= 10 and action <= 12:  # Red action cards
                reward += 3
            elif action == 13:  # Red wild card
                reward += 6
            elif action == 14:  # Red wild and draw 4 card
                reward += 10

            elif action >= 15 and action <= 24:  # Green number cards
                reward += 1
            elif action >= 25 and action <= 27:  # Green action cards
                reward += 3
            elif action == 28:  # Green wild card
                reward += 6
            elif action == 29:  # Green wild and draw 4 card
                reward += 10

            elif action >= 30 and action <= 39:  # Blue number cards
                reward += 1
            elif action >= 40 and action <= 42:  # Blue action cards
                reward += 3
            elif action == 43:  # Blue wild card
                reward += 6
            elif action == 44:  # Blue wild and draw 4 card
                reward += 10

            elif action >= 45 and action <= 54:  # Yellow number cards
                reward += 1
            elif action >= 55 and action <= 57:  # Yellow action cards
                reward += 3
            elif action == 58:  # Yellow wild card
                reward += 6
            elif action == 59:  # Yellow wild and draw 4 card
                reward += 10
                
            adjusted_traj.append((state, action, reward, next_state, done))
        adjusted_trajectories.append(adjusted_traj)
    return adjusted_trajectories

# %%
def adjust_rewards(trajectories, payoffs):
    adjusted_trajectories = []
    for traj in trajectories:
        adjusted_traj = []
        for state, action, reward, next_state, done in traj:
            # Actual game state details
            raw_obs = state['raw_obs']
            
            # Retrieve the number of cards in player's hand
            num_cards_player = len(raw_obs['hand'])
            
            # Provide the number of cards for each player with the current player being index 0
            num_cards_opponent = raw_obs['num_cards'][1] if raw_obs['current_player'] == 0 else raw_obs['num_cards'][0]

            if action == 60:  # Draw a card
                reward -= max(1, 3 - num_cards_player / 7)

            # Adjust rewards for action cards based on the opponent's hand size
            action_card_reward_multiplier = max(1, (7 - num_cards_opponent) / 7)

            if action in range(10, 15) or action in range(25, 30) or action in range(40, 45) or action in range(55, 60):
                reward += 2 * action_card_reward_multiplier

            if action in range(0, 10) or action in range(15, 25) or action in range(30, 40) or action in range(45, 55):
                reward += 1 + (3 - num_cards_player / 7)

            adjusted_traj.append((state, action, reward, next_state, done))
        adjusted_trajectories.append(adjusted_traj)
    return adjusted_trajectories

# %% [markdown]
# # Building out the simulation
#
# Previously, the code would run an entire/complete simulation. However, this restricts the ability to learn from moves within the simulation.

# %%
episode_num = 25000  # Number of episodes 

evaluate_every = 1000 # Evaluate the agent every X episodes
evaluate_num = 100  # Number of games played in evaluation

with Logger(log_dir) as logger:
    for episode in range(episode_num):  # Number of episodes

        trajectories, payoffs = env.run(is_training=True)

        # Assuming 'payoffs' are the game outcomes for each player
        for i, payoff in enumerate(payoffs):
            if payoff > 0:  # Assuming a positive payoff means winning
                payoffs[i] = 100
            else:
                payoffs[i] = -25

        trajectories = reorganize(trajectories, payoffs)

        # After reorganizing the trajectories, adjust the rewards
        trajectories = adjust_rewards(trajectories, payoffs)
        # print(trajectories[0])

        for ts in trajectories[0]:
            agent.feed(ts)
        
        if episode % evaluate_every == 0:
                logger.log_performance(
                    episode,
                    tournament(
                        env,
                        evaluate_num,
                    )[0]
                )

    # Get the paths
    csv_path, fig_path = logger.csv_path, logger.fig_path
# Out:
# INFO - Step 576331, rl-loss: 83.275657653808625
# ----------------------------------------
#   episode      |  0
#   reward       |  0.18
# ----------------------------------------
# INFO - Step 576400, rl-loss: 87.889739990234385
# INFO - Copied model parameters to target network.
# INFO - Step 576500, rl-loss: 350.67080688476565
# INFO - Copied model parameters to target network.
# INFO - Step 576600, rl-loss: 188.09564208984375
# INFO - Copied model parameters to target network.
# INFO - Step 576700, rl-loss: 343.37100219726565
# INFO - Copied model parameters to target network.
# INFO - Step 576800, rl-loss: 209.85687255859375
# INFO - Copied model parameters to target network.
# INFO - Step 576900, rl-loss: 338.61404418945315
# INFO - Copied model parameters to target network.
# INFO - Step 577000, rl-loss: 44.770011901855476
# INFO - Copied model parameters to target network.
# INFO - Step 577100, rl-loss: 382.26092529296875
# INFO - Copied model parameters to target network.
# INFO - Step 577200, rl-loss: 406.94781494140625
# INFO - Copied model parameters to target network.
# INFO - Step 577300, rl-loss: 133.60169982910156
# INFO - Copied model parameters to target network.
# INFO - Step 577400, rl-loss: 93.144035339355475
# INFO - Copied model parameters to target network.
# INFO - Step 577500, rl-loss: 287.60977172851568
# INFO - Copied model parameters to target network.
# INFO - Step 577600, rl-loss: 139.39486694335938
# INFO - Copied model parameters to target network.
# INFO - Step 577700, rl-loss: 154.90884399414062
# INFO - Copied model parameters to target network.
# INFO - Step 577800, rl-loss: 270.60327148437558
# INFO - Copied model parameters to target network.
# INFO - Step 577900, rl-loss: 131.32978820800782
# INFO - Copied model parameters to target network.
# INFO - Step 578000, rl-loss: 184.89807128906252
# INFO - Copied model parameters to target network.
# INFO - Step 578100, rl-loss: 262.48898315429696
# INFO - Copied model parameters to target network.
# INFO - Step 578200, rl-loss: 202.64962768554688
# INFO - Copied model parameters to target network.
# INFO - Step 578300, rl-loss: 333.13543701171875
# INFO - Copied model parameters to target network.
# INFO - Step 578400, rl-loss: 80.476676940917972
# INFO - Copied model parameters to target network.
# INFO - Step 578500, rl-loss: 181.07934570312525
# INFO - Copied model parameters to target network.
# INFO - Step 578600, rl-loss: 330.30761718751875
# INFO - Copied model parameters to target network.
# INFO - Step 578700, rl-loss: 133.00659179687575
# INFO - Copied model parameters to target network.
# INFO - Step 578800, rl-loss: 122.86542510986328
# INFO - Copied model parameters to target network.
# INFO - Step 578900, rl-loss: 130.59700012207038
# INFO - Copied model parameters to target network.
# INFO - Step 579000, rl-loss: 316.24877929687512
# INFO - Copied model parameters to target network.
# INFO - Step 579100, rl-loss: 99.794601440429694
# INFO - Copied model parameters to target network.
# INFO - Step 579200, rl-loss: 280.09051513671875
# INFO - Copied model parameters to target network.
# INFO - Step 579300, rl-loss: 445.08544921875948
# INFO - Copied model parameters to target network.
# INFO - Step 579400, rl-loss: 63.901374816894538
# INFO - Copied model parameters to target network.
# INFO - Step 579500, rl-loss: 63.168830871582035
# INFO - Copied model parameters to target network.
# INFO - Step 579600, rl-loss: 114.76162719726562
# INFO - Copied model parameters to target network.
# INFO - Step 579700, rl-loss: 235.43263244628906
# INFO - Copied model parameters to target network.
# INFO - Step 579800, rl-loss: 132.36683654785156
# INFO - Copied model parameters to target network.
# INFO - Step 579900, rl-loss: 326.06121826171875
# INFO - Copied model parameters to target network.
# INFO - Step 580000, rl-loss: 155.02906799316406
# INFO - Copied model parameters to target network.
# INFO - Step 580100, rl-loss: 355.94146728515625
# INFO - Copied model parameters to target network.
# INFO - Step 580200, rl-loss: 196.01585388183594
# INFO - Copied model parameters to target network.
# INFO - Step 580300, rl-loss: 154.29310607910156
# INFO - Copied model parameters to target network.
# INFO - Step 580400, rl-loss: 190.46200561523438
# INFO - Copied model parameters to target network.
# INFO - Step 580500, rl-loss: 154.62847900390625
# INFO - Copied model parameters to target network.
# INFO - Step 580600, rl-loss: 214.58509826660156
# INFO - Copied model parameters to target network.
# INFO - Step 580700, rl-loss: 243.51927185058594
# INFO - Copied model parameters to target network.
# INFO - Step 580800, rl-loss: 177.23693847656255
# INFO - Copied model parameters to target network.
# INFO - Step 580900, rl-loss: 250.48303222656258
# INFO - Copied model parameters to target network.
# INFO - Step 581000, rl-loss: 425.82696533203125
# INFO - Copied model parameters to target network.
# INFO - Step 581100, rl-loss: 326.99432373046875
# INFO - Copied model parameters to target network.
# INFO - Step 581200, rl-loss: 280.73327636718755
# INFO - Copied model parameters to target network.
# INFO - Step 581300, rl-loss: 281.72628784179694
# INFO - Copied model parameters to target network.
# INFO - Step 581400, rl-loss: 373.89849853515625
# INFO - Copied model parameters to target network.
# INFO - Step 581500, rl-loss: 92.368583679199225
# INFO - Copied model parameters to target network.
# INFO - Step 581600, rl-loss: 78.690048217773445
# INFO - Copied model parameters to target network.
# INFO - Step 581700, rl-loss: 197.07952880859375
# INFO - Copied model parameters to target network.
# INFO - Step 581800, rl-loss: 154.03967285156252
# INFO - Copied model parameters to target network.
# INFO - Step 581900, rl-loss: 77.429275512695315
# INFO - Copied model parameters to target network.
# INFO - Step 582000, rl-loss: 222.80464172363285
# INFO - Copied model parameters to target network.
# INFO - Step 582100, rl-loss: 241.29257202148438
# INFO - Copied model parameters to target network.
# INFO - Step 582200, rl-loss: 70.343215942382818
# INFO - Copied model parameters to target network.
# INFO - Step 582300, rl-loss: 183.37286376953125
# INFO - Copied model parameters to target network.
# INFO - Step 582400, rl-loss: 488.28417968758755
# INFO - Copied model parameters to target network.
# INFO - Step 582500, rl-loss: 175.32376098632812
# INFO - Copied model parameters to target network.
# INFO - Step 582600, rl-loss: 336.37109375218758
# INFO - Copied model parameters to target network.
# INFO - Step 582700, rl-loss: 167.49049377441406
# INFO - Copied model parameters to target network.
# INFO - Step 582800, rl-loss: 171.41160583496094
# INFO - Copied model parameters to target network.
# INFO - Step 582900, rl-loss: 185.38923645019535
# INFO - Copied model parameters to target network.
# INFO - Step 583000, rl-loss: 286.90542602539065
# INFO - Copied model parameters to target network.
# INFO - Step 583100, rl-loss: 388.57977294921875
# INFO - Copied model parameters to target network.
# INFO - Step 583200, rl-loss: 245.02626037597656
# INFO - Copied model parameters to target network.
# INFO - Step 583300, rl-loss: 127.98383331298828
# INFO - Copied model parameters to target network.
# INFO - Step 583400, rl-loss: 213.22909545898438
# INFO - Copied model parameters to target network.
# INFO - Step 583500, rl-loss: 156.62568664550785
# INFO - Copied model parameters to target network.
# INFO - Step 583600, rl-loss: 171.57684326171875
# INFO - Copied model parameters to target network.
# INFO - Step 583700, rl-loss: 150.81466674804688
# INFO - Copied model parameters to target network.
# INFO - Step 583800, rl-loss: 217.95941162109375
# INFO - Copied model parameters to target network.
# INFO - Step 583900, rl-loss: 501.75549316406256
# INFO - Copied model parameters to target network.
# INFO - Step 584000, rl-loss: 221.68780517578125
# INFO - Copied model parameters to target network.
# INFO - Step 584100, rl-loss: 240.34771728515625
# INFO - Copied model parameters to target network.
# INFO - Step 584200, rl-loss: 202.62429809570312
# INFO - Copied model parameters to target network.
# INFO - Step 584300, rl-loss: 248.40606689453125
# INFO - Copied model parameters to target network.
# INFO - Step 584400, rl-loss: 279.15270996093758
# INFO - Copied model parameters to target network.
# INFO - Step 584500, rl-loss: 288.48117065429692
# INFO - Copied model parameters to target network.
# INFO - Step 584600, rl-loss: 210.89021301269534
# INFO - Copied model parameters to target network.
# INFO - Step 584700, rl-loss: 215.47497558593755
# INFO - Copied model parameters to target network.
# INFO - Step 584800, rl-loss: 185.61053466796875
# INFO - Copied model parameters to target network.
# INFO - Step 584900, rl-loss: 88.289260864257818
# INFO - Copied model parameters to target network.
# INFO - Step 585000, rl-loss: 439.67553710937562
# INFO - Copied model parameters to target network.
# INFO - Step 585100, rl-loss: 199.86547851562575
# INFO - Copied model parameters to target network.
# INFO - Step 585200, rl-loss: 204.74005126953125
# INFO - Copied model parameters to target network.
# INFO - Step 585300, rl-loss: 137.18460083007812
# INFO - Copied model parameters to target network.
# INFO - Step 585400, rl-loss: 192.99133300781258
# INFO - Copied model parameters to target network.
# INFO - Step 585500, rl-loss: 140.62887573242188
# INFO - Copied model parameters to target network.
# INFO - Step 585600, rl-loss: 230.37538146972656
# INFO - Copied model parameters to target network.
# INFO - Step 585700, rl-loss: 260.23004150390625
# INFO - Copied model parameters to target network.
# INFO - Step 585800, rl-loss: 125.55672454833984
# INFO - Copied model parameters to target network.
# INFO - Step 585900, rl-loss: 384.85891723632815
# INFO - Copied model parameters to target network.
# INFO - Step 586000, rl-loss: 129.98843383789062
# INFO - Copied model parameters to target network.
# INFO - Step 586100, rl-loss: 189.47235107421875
# INFO - Copied model parameters to target network.
# INFO - Step 586200, rl-loss: 282.75305175781252
# INFO - Copied model parameters to target network.
# INFO - Step 586300, rl-loss: 158.23039245605472
# INFO - Copied model parameters to target network.
# INFO - Step 586400, rl-loss: 378.94793701171875
# INFO - Copied model parameters to target network.
# INFO - Step 586500, rl-loss: 259.13577270507818
# INFO - Copied model parameters to target network.
# INFO - Step 586600, rl-loss: 344.44107055664068
# INFO - Copied model parameters to target network.
# INFO - Step 586700, rl-loss: 79.123634338378998
# INFO - Copied model parameters to target network.
# INFO - Step 586800, rl-loss: 126.50880432128906
# INFO - Copied model parameters to target network.
# INFO - Step 586900, rl-loss: 113.12913513183594
# INFO - Copied model parameters to target network.
# INFO - Step 587000, rl-loss: 240.79119873046875
# INFO - Copied model parameters to target network.
# INFO - Step 587100, rl-loss: 88.689437866210943
# INFO - Copied model parameters to target network.
# INFO - Step 587200, rl-loss: 185.78709411621094
# INFO - Copied model parameters to target network.
# INFO - Step 587300, rl-loss: 224.66706848144532
# INFO - Copied model parameters to target network.
# INFO - Step 587400, rl-loss: 186.30328369140625
# INFO - Copied model parameters to target network.
# INFO - Step 587500, rl-loss: 104.23843383789062
# INFO - Copied model parameters to target network.
# INFO - Step 587600, rl-loss: 254.20053100585938
# INFO - Copied model parameters to target network.
# INFO - Step 587700, rl-loss: 150.88377380371094
# INFO - Copied model parameters to target network.
# INFO - Step 587800, rl-loss: 204.25726318359375
# INFO - Copied model parameters to target network.
# INFO - Step 587900, rl-loss: 151.46247863769538
# INFO - Copied model parameters to target network.
# INFO - Step 588000, rl-loss: 337.16693115234375
# INFO - Copied model parameters to target network.
# INFO - Step 588100, rl-loss: 107.96139526367188
# INFO - Copied model parameters to target network.
# INFO - Step 588200, rl-loss: 96.962722778320318
# INFO - Copied model parameters to target network.
# INFO - Step 588300, rl-loss: 367.69412231445312
# INFO - Copied model parameters to target network.
# INFO - Step 588400, rl-loss: 176.20544433593758
# INFO - Copied model parameters to target network.
# INFO - Step 588500, rl-loss: 431.98318481445312
# INFO - Copied model parameters to target network.
# INFO - Step 588600, rl-loss: 157.66838073730476
# INFO - Copied model parameters to target network.
# INFO - Step 588700, rl-loss: 307.13494873046875
# INFO - Copied model parameters to target network.
# INFO - Step 588800, rl-loss: 233.40702819824222
# INFO - Copied model parameters to target network.
# INFO - Step 588900, rl-loss: 492.63668823242195
# INFO - Copied model parameters to target network.
# INFO - Step 589000, rl-loss: 145.48583984375198
# INFO - Copied model parameters to target network.
# INFO - Step 589100, rl-loss: 222.07518005371094
# INFO - Copied model parameters to target network.
# INFO - Step 589200, rl-loss: 378.57507324218752
# INFO - Copied model parameters to target network.
# INFO - Step 589300, rl-loss: 278.70736694335943
# INFO - Copied model parameters to target network.
# INFO - Step 589400, rl-loss: 398.53814697265625
# INFO - Copied model parameters to target network.
# INFO - Step 589500, rl-loss: 86.758255004882816
# INFO - Copied model parameters to target network.
# INFO - Step 589600, rl-loss: 365.41339111328125
# INFO - Copied model parameters to target network.
# INFO - Step 589700, rl-loss: 164.70651245117188
# INFO - Copied model parameters to target network.
# INFO - Step 589800, rl-loss: 222.49487304687512
# INFO - Copied model parameters to target network.
# INFO - Step 589900, rl-loss: 255.39772033691406
# INFO - Copied model parameters to target network.
# INFO - Step 590000, rl-loss: 89.853866577148446
# INFO - Copied model parameters to target network.
# INFO - Step 590100, rl-loss: 380.37896728515625
# INFO - Copied model parameters to target network.
# INFO - Step 590200, rl-loss: 124.59539794921875
# INFO - Copied model parameters to target network.
# INFO - Step 590300, rl-loss: 98.682479858398444
# INFO - Copied model parameters to target network.
# INFO - Step 590400, rl-loss: 288.66979980468754
# INFO - Copied model parameters to target network.
# INFO - Step 590500, rl-loss: 554.89331054687525
# INFO - Copied model parameters to target network.
# INFO - Step 590600, rl-loss: 173.66281127929688
# INFO - Copied model parameters to target network.
# INFO - Step 590700, rl-loss: 174.46124267578125
# INFO - Copied model parameters to target network.
# INFO - Step 590800, rl-loss: 256.35711669921875
# INFO - Copied model parameters to target network.
# INFO - Step 590900, rl-loss: 350.25488281254062
# INFO - Copied model parameters to target network.
# INFO - Step 591000, rl-loss: 268.24203491210945
# INFO - Copied model parameters to target network.
# INFO - Step 591100, rl-loss: 264.27493286132818
# INFO - Copied model parameters to target network.
# INFO - Step 591200, rl-loss: 124.49230957031256
# INFO - Copied model parameters to target network.
# INFO - Step 591300, rl-loss: 272.65719604492195
# INFO - Copied model parameters to target network.
# INFO - Step 591400, rl-loss: 163.94723510742188
# INFO - Copied model parameters to target network.
# INFO - Step 591500, rl-loss: 383.63516235351562
# INFO - Copied model parameters to target network.
# INFO - Step 591600, rl-loss: 157.96617126464844
# INFO - Copied model parameters to target network.
# INFO - Step 591700, rl-loss: 123.43498229980469
# INFO - Copied model parameters to target network.
# INFO - Step 591800, rl-loss: 92.279525756835945
# INFO - Copied model parameters to target network.
# INFO - Step 591900, rl-loss: 155.63183593755314
# INFO - Copied model parameters to target network.
# INFO - Step 592000, rl-loss: 238.10694885253906
# INFO - Copied model parameters to target network.
# INFO - Step 592100, rl-loss: 281.52133178710947
# INFO - Copied model parameters to target network.
# INFO - Step 592200, rl-loss: 250.05752563476562
# INFO - Copied model parameters to target network.
# INFO - Step 592300, rl-loss: 278.46295166015625
# INFO - Copied model parameters to target network.
# INFO - Step 592400, rl-loss: 183.47259521484375
# INFO - Copied model parameters to target network.
# INFO - Step 592500, rl-loss: 214.75973510742188
# INFO - Copied model parameters to target network.
# INFO - Step 592600, rl-loss: 144.26113891601562
# INFO - Copied model parameters to target network.
# INFO - Step 592700, rl-loss: 116.06756591796875
# INFO - Copied model parameters to target network.
# INFO - Step 592800, rl-loss: 203.29856872558594
# INFO - Copied model parameters to target network.
# INFO - Step 592900, rl-loss: 334.46533203125755
# INFO - Copied model parameters to target network.
# INFO - Step 593000, rl-loss: 67.114028930664062
# INFO - Copied model parameters to target network.
# INFO - Step 593100, rl-loss: 195.91990661621094
# INFO - Copied model parameters to target network.
# INFO - Step 593200, rl-loss: 431.04406738281256
# INFO - Copied model parameters to target network.
# INFO - Step 593300, rl-loss: 361.87619018554695
# INFO - Copied model parameters to target network.
# INFO - Step 593400, rl-loss: 149.51245117187594
# INFO - Copied model parameters to target network.
# INFO - Step 593500, rl-loss: 94.571456909179694
# INFO - Copied model parameters to target network.
# INFO - Step 593600, rl-loss: 110.83763122558594
# INFO - Copied model parameters to target network.
# INFO - Step 593700, rl-loss: 179.37765502929688
# INFO - Copied model parameters to target network.
# INFO - Step 593800, rl-loss: 219.40512084960938
# INFO - Copied model parameters to target network.
# INFO - Step 593900, rl-loss: 354.05728149414061
# INFO - Copied model parameters to target network.
# INFO - Step 594000, rl-loss: 94.990180969238288
# INFO - Copied model parameters to target network.
# INFO - Step 594100, rl-loss: 250.79824829101562
# INFO - Copied model parameters to target network.
# INFO - Step 594200, rl-loss: 121.92134857177734
# INFO - Copied model parameters to target network.
# INFO - Step 594300, rl-loss: 212.95648193359375
# INFO - Copied model parameters to target network.
# INFO - Step 594400, rl-loss: 123.18540191650396
# INFO - Copied model parameters to target network.
# INFO - Step 594500, rl-loss: 188.21966552734375
# INFO - Copied model parameters to target network.
# INFO - Step 594600, rl-loss: 417.59143066406255
# INFO - Copied model parameters to target network.
# INFO - Step 594700, rl-loss: 126.68376159667969
# INFO - Copied model parameters to target network.
# INFO - Step 594800, rl-loss: 154.10057067871094
# INFO - Copied model parameters to target network.
# INFO - Step 594900, rl-loss: 173.11166381835938
# INFO - Copied model parameters to target network.
# INFO - Step 595000, rl-loss: 381.25082397460948
# INFO - Copied model parameters to target network.
# INFO - Step 595100, rl-loss: 280.95382690429694
# INFO - Copied model parameters to target network.
# INFO - Step 595200, rl-loss: 194.33360290527344
# INFO - Copied model parameters to target network.
# INFO - Step 595300, rl-loss: 159.04571533203125
# INFO - Copied model parameters to target network.
# INFO - Step 595400, rl-loss: 618.74719238281258
# INFO - Copied model parameters to target network.
# INFO - Step 595500, rl-loss: 112.01702117919922
# INFO - Copied model parameters to target network.
# INFO - Step 595600, rl-loss: 143.18392944335938
# INFO - Copied model parameters to target network.
# INFO - Step 595700, rl-loss: 163.89694213867188
# INFO - Copied model parameters to target network.
# INFO - Step 595800, rl-loss: 124.50639343261719
# INFO - Copied model parameters to target network.
# INFO - Step 595900, rl-loss: 179.32582092285156
# INFO - Copied model parameters to target network.
# INFO - Step 596000, rl-loss: 106.32128906254535
# INFO - Copied model parameters to target network.
# INFO - Step 596100, rl-loss: 203.93356323242188
# INFO - Copied model parameters to target network.
# INFO - Step 596200, rl-loss: 286.93395996093755
# INFO - Copied model parameters to target network.
# INFO - Step 596300, rl-loss: 226.72007751464844
# INFO - Copied model parameters to target network.
# INFO - Step 596400, rl-loss: 176.58287048339844
# INFO - Copied model parameters to target network.
# INFO - Step 596500, rl-loss: 330.27923583984375
# INFO - Copied model parameters to target network.
# INFO - Step 596600, rl-loss: 190.51177978515625
# INFO - Copied model parameters to target network.
# INFO - Step 596700, rl-loss: 319.73529052734375
# INFO - Copied model parameters to target network.
# INFO - Step 596800, rl-loss: 270.94381713867195
# INFO - Copied model parameters to target network.
# INFO - Step 596900, rl-loss: 247.11541748046875
# INFO - Copied model parameters to target network.
# INFO - Step 597000, rl-loss: 103.58264160156255
# INFO - Copied model parameters to target network.
# INFO - Step 597100, rl-loss: 278.53216552734375
# INFO - Copied model parameters to target network.
# INFO - Step 597200, rl-loss: 266.67669677734375
# INFO - Copied model parameters to target network.
# INFO - Step 597300, rl-loss: 248.38583374023438
# INFO - Copied model parameters to target network.
# INFO - Step 597400, rl-loss: 149.32928466796875
# INFO - Copied model parameters to target network.
# INFO - Step 597500, rl-loss: 193.95796203613285
# INFO - Copied model parameters to target network.
# INFO - Step 597600, rl-loss: 322.69323730468755
# INFO - Copied model parameters to target network.
# INFO - Step 597700, rl-loss: 112.60224914550781
# INFO - Copied model parameters to target network.
# INFO - Step 597800, rl-loss: 317.87753295898446
# INFO - Copied model parameters to target network.
# INFO - Step 597900, rl-loss: 145.11184692382812
# INFO - Copied model parameters to target network.
# INFO - Step 598000, rl-loss: 144.11709594726562
# INFO - Copied model parameters to target network.
# INFO - Step 598100, rl-loss: 146.03202819824228
# INFO - Copied model parameters to target network.
# INFO - Step 598200, rl-loss: 557.24078369140625
# INFO - Copied model parameters to target network.
# INFO - Step 598300, rl-loss: 556.81768798828125
# INFO - Copied model parameters to target network.
# INFO - Step 598400, rl-loss: 279.85180664062575
# INFO - Copied model parameters to target network.
# INFO - Step 598500, rl-loss: 126.01071166992188
# INFO - Copied model parameters to target network.
# INFO - Step 598524, rl-loss: 178.78063964843752
# ----------------------------------------
#   episode      |  1000
#   reward       |  0.18
# ----------------------------------------
# INFO - Step 598600, rl-loss: 199.90647888183594
# INFO - Copied model parameters to target network.
# INFO - Step 598700, rl-loss: 122.22840118408203
# INFO - Copied model parameters to target network.
# INFO - Step 598800, rl-loss: 187.24537658691406
# INFO - Copied model parameters to target network.
# INFO - Step 598900, rl-loss: 361.86245727539066
# INFO - Copied model parameters to target network.
# INFO - Step 599000, rl-loss: 134.48716735839844
# INFO - Copied model parameters to target network.
# INFO - Step 599100, rl-loss: 141.51638793945312
# INFO - Copied model parameters to target network.
# INFO - Step 599200, rl-loss: 437.23760986328125
# INFO - Copied model parameters to target network.
# INFO - Step 599300, rl-loss: 221.35408020019534
# INFO - Copied model parameters to target network.
# INFO - Step 599400, rl-loss: 211.02529907226562
# INFO - Copied model parameters to target network.
# INFO - Step 599500, rl-loss: 241.43038940429688
# INFO - Copied model parameters to target network.
# INFO - Step 599600, rl-loss: 287.36355590820315
# INFO - Copied model parameters to target network.
# INFO - Step 599700, rl-loss: 115.31636047363281
# INFO - Copied model parameters to target network.
# INFO - Step 599800, rl-loss: 178.61444091796875
# INFO - Copied model parameters to target network.
# INFO - Step 599900, rl-loss: 154.67115783691406
# INFO - Copied model parameters to target network.
# INFO - Step 600000, rl-loss: 211.08749389648438
# INFO - Copied model parameters to target network.
# INFO - Step 600100, rl-loss: 139.09954833984375
# INFO - Copied model parameters to target network.
# INFO - Step 600200, rl-loss: 125.23390960693368
# INFO - Copied model parameters to target network.
# INFO - Step 600300, rl-loss: 154.15936279296875
# INFO - Copied model parameters to target network.
# INFO - Step 600400, rl-loss: 179.59375634765625
# INFO - Copied model parameters to target network.
# INFO - Step 600500, rl-loss: 592.38269042968758
# INFO - Copied model parameters to target network.
# INFO - Step 600600, rl-loss: 252.88874816894532
# INFO - Copied model parameters to target network.
# INFO - Step 600700, rl-loss: 328.16754150390625
# INFO - Copied model parameters to target network.
# INFO - Step 600800, rl-loss: 271.24765014648445
# INFO - Copied model parameters to target network.
# INFO - Step 600900, rl-loss: 330.31155395507814
# INFO - Copied model parameters to target network.
# INFO - Step 601000, rl-loss: 326.47650146484375
# INFO - Copied model parameters to target network.
# INFO - Step 601100, rl-loss: 224.86215209960938
# INFO - Copied model parameters to target network.
# INFO - Step 601200, rl-loss: 241.69140625101566
# INFO - Copied model parameters to target network.
# INFO - Step 601300, rl-loss: 319.84951782226565
# INFO - Copied model parameters to target network.
# INFO - Step 601400, rl-loss: 183.85177612304688
# INFO - Copied model parameters to target network.
# INFO - Step 601500, rl-loss: 115.28677368164062
# INFO - Copied model parameters to target network.
# INFO - Step 601600, rl-loss: 518.22753906252656
# INFO - Copied model parameters to target network.
# INFO - Step 601700, rl-loss: 59.917484283447266
# INFO - Copied model parameters to target network.
# INFO - Step 601800, rl-loss: 197.73413085937565
# INFO - Copied model parameters to target network.
# INFO - Step 601900, rl-loss: 186.27336120605478
# INFO - Copied model parameters to target network.
# INFO - Step 602000, rl-loss: 426.64883422851565
# INFO - Copied model parameters to target network.
# INFO - Step 602100, rl-loss: 209.35653686523438
# INFO - Copied model parameters to target network.
# INFO - Step 602200, rl-loss: 65.145896911621125
# INFO - Copied model parameters to target network.
# INFO - Step 602300, rl-loss: 784.42449951171884
# INFO - Copied model parameters to target network.
# INFO - Step 602400, rl-loss: 137.45797729492188
# INFO - Copied model parameters to target network.
# INFO - Step 602500, rl-loss: 110.09587097167969
# INFO - Copied model parameters to target network.
# INFO - Step 602600, rl-loss: 235.53112792968758
# INFO - Copied model parameters to target network.
# INFO - Step 602700, rl-loss: 225.23089599609375
# INFO - Copied model parameters to target network.
# INFO - Step 602800, rl-loss: 193.18852233886725
# INFO - Copied model parameters to target network.
# INFO - Step 602900, rl-loss: 296.90551757812525
# INFO - Copied model parameters to target network.
# INFO - Step 603000, rl-loss: 102.16831207275397
# INFO - Copied model parameters to target network.
# INFO - Step 603100, rl-loss: 72.605621337890626
# INFO - Copied model parameters to target network.
# INFO - Step 603200, rl-loss: 345.40542602539065
# INFO - Copied model parameters to target network.
# INFO - Step 603300, rl-loss: 300.43878173828125
# INFO - Copied model parameters to target network.
# INFO - Step 603400, rl-loss: 148.20675659179688
# INFO - Copied model parameters to target network.
# INFO - Step 603500, rl-loss: 246.00637817382812
# INFO - Copied model parameters to target network.
# INFO - Step 603600, rl-loss: 166.52325439453125
# INFO - Copied model parameters to target network.
# INFO - Step 603700, rl-loss: 104.89561462402344
# INFO - Copied model parameters to target network.
# INFO - Step 603800, rl-loss: 92.903785705566438
# INFO - Copied model parameters to target network.
# INFO - Step 603900, rl-loss: 77.558525085449225
# INFO - Copied model parameters to target network.
# INFO - Step 604000, rl-loss: 246.88867187575788
# INFO - Copied model parameters to target network.
# INFO - Step 604100, rl-loss: 325.16885375976568
# INFO - Copied model parameters to target network.
# INFO - Step 604200, rl-loss: 73.721069335937512
# INFO - Copied model parameters to target network.
# INFO - Step 604300, rl-loss: 75.372932434082035
# INFO - Copied model parameters to target network.
# INFO - Step 604400, rl-loss: 283.64617919921875
# INFO - Copied model parameters to target network.
# INFO - Step 604500, rl-loss: 321.85778808593756
# INFO - Copied model parameters to target network.
# INFO - Step 604600, rl-loss: 121.99629211425781
# INFO - Copied model parameters to target network.
# INFO - Step 604700, rl-loss: 261.42846679687512
# INFO - Copied model parameters to target network.
# INFO - Step 604800, rl-loss: 487.79644775390625
# INFO - Copied model parameters to target network.
# INFO - Step 604900, rl-loss: 317.70227050781255
# INFO - Copied model parameters to target network.
# INFO - Step 605000, rl-loss: 102.66486358642578
# INFO - Copied model parameters to target network.
# INFO - Step 605100, rl-loss: 124.31265258789062
# INFO - Copied model parameters to target network.
# INFO - Step 605200, rl-loss: 444.49401855468755
# INFO - Copied model parameters to target network.
# INFO - Step 605300, rl-loss: 48.258304595947266
# INFO - Copied model parameters to target network.
# INFO - Step 605400, rl-loss: 160.23059082031256
# INFO - Copied model parameters to target network.
# INFO - Step 605500, rl-loss: 239.58445739746094
# INFO - Copied model parameters to target network.
# INFO - Step 605600, rl-loss: 408.15643310546875
# INFO - Copied model parameters to target network.
# INFO - Step 605700, rl-loss: 234.11453247070312
# INFO - Copied model parameters to target network.
# INFO - Step 605800, rl-loss: 245.84521484375472
# INFO - Copied model parameters to target network.
# INFO - Step 605900, rl-loss: 151.28781127929688
# INFO - Copied model parameters to target network.
# INFO - Step 606000, rl-loss: 92.881042480468759
# INFO - Copied model parameters to target network.
# INFO - Step 606100, rl-loss: 173.59542846679688
# INFO - Copied model parameters to target network.
# INFO - Step 606200, rl-loss: 114.52947998046875
# INFO - Copied model parameters to target network.
# INFO - Step 606300, rl-loss: 237.10534667968758
# INFO - Copied model parameters to target network.
# INFO - Step 606400, rl-loss: 229.98512268066406
# INFO - Copied model parameters to target network.
# INFO - Step 606500, rl-loss: 76.941787719726562
# INFO - Copied model parameters to target network.
# INFO - Step 606600, rl-loss: 224.98190307617188
# INFO - Copied model parameters to target network.
# INFO - Step 606700, rl-loss: 371.10571289062585
# INFO - Copied model parameters to target network.
# INFO - Step 606800, rl-loss: 325.58026123046875
# INFO - Copied model parameters to target network.
# INFO - Step 606900, rl-loss: 174.90155029296875
# INFO - Copied model parameters to target network.
# INFO - Step 607000, rl-loss: 90.058456420898446
# INFO - Copied model parameters to target network.
# INFO - Step 607100, rl-loss: 389.85751342773445
# INFO - Copied model parameters to target network.
# INFO - Step 607200, rl-loss: 76.642333984375938
# INFO - Copied model parameters to target network.
# INFO - Step 607300, rl-loss: 222.06564331054688
# INFO - Copied model parameters to target network.
# INFO - Step 607400, rl-loss: 180.37339782714844
# INFO - Copied model parameters to target network.
# INFO - Step 607500, rl-loss: 305.78118896484375
# INFO - Copied model parameters to target network.
# INFO - Step 607600, rl-loss: 67.606323242187595
# INFO - Copied model parameters to target network.
# INFO - Step 607700, rl-loss: 113.58134460449219
# INFO - Copied model parameters to target network.
# INFO - Step 607800, rl-loss: 110.47688293457031
# INFO - Copied model parameters to target network.
# INFO - Step 607900, rl-loss: 199.95663452148438
# INFO - Copied model parameters to target network.
# INFO - Step 608000, rl-loss: 129.81433105468754
# INFO - Copied model parameters to target network.
# INFO - Step 608100, rl-loss: 179.37171936035156
# INFO - Copied model parameters to target network.
# INFO - Step 608200, rl-loss: 248.61694335937558
# INFO - Copied model parameters to target network.
# INFO - Step 608300, rl-loss: 130.47973632812512
# INFO - Copied model parameters to target network.
# INFO - Step 608400, rl-loss: 166.42675781258968
# INFO - Copied model parameters to target network.
# INFO - Step 608500, rl-loss: 78.538269042968752
# INFO - Copied model parameters to target network.
# INFO - Step 608600, rl-loss: 191.88978576660156
# INFO - Copied model parameters to target network.
# INFO - Step 608700, rl-loss: 156.74063110351562
# INFO - Copied model parameters to target network.
# INFO - Step 608800, rl-loss: 283.13809204101562
# INFO - Copied model parameters to target network.
# INFO - Step 608900, rl-loss: 388.69555664062588
# INFO - Copied model parameters to target network.
# INFO - Step 609000, rl-loss: 164.53611755371094
# INFO - Copied model parameters to target network.
# INFO - Step 609100, rl-loss: 349.83349609375252
# INFO - Copied model parameters to target network.
# INFO - Step 609200, rl-loss: 180.47254943847656
# INFO - Copied model parameters to target network.
# INFO - Step 609300, rl-loss: 120.37310791015625
# INFO - Copied model parameters to target network.
# INFO - Step 609400, rl-loss: 385.47845458984375
# INFO - Copied model parameters to target network.
# INFO - Step 609500, rl-loss: 448.90820312562531
# INFO - Copied model parameters to target network.
# INFO - Step 609600, rl-loss: 393.57812516992188
# INFO - Copied model parameters to target network.
# INFO - Step 609700, rl-loss: 268.48507690429695
# INFO - Copied model parameters to target network.
# INFO - Step 609800, rl-loss: 226.20266723632812
# INFO - Copied model parameters to target network.
# INFO - Step 609900, rl-loss: 247.15548706054688
# INFO - Copied model parameters to target network.
# INFO - Step 610000, rl-loss: 486.38397216796875
# INFO - Copied model parameters to target network.
# INFO - Step 610100, rl-loss: 435.65338134765625
# INFO - Copied model parameters to target network.
# INFO - Step 610200, rl-loss: 96.311401367187575
# INFO - Copied model parameters to target network.
# INFO - Step 610300, rl-loss: 147.63194274902344
# INFO - Copied model parameters to target network.
# INFO - Step 610400, rl-loss: 307.25891113281252
# INFO - Copied model parameters to target network.
# INFO - Step 610500, rl-loss: 201.33930969238288
# INFO - Copied model parameters to target network.
# INFO - Step 610600, rl-loss: 400.95318603515625
# INFO - Copied model parameters to target network.
# INFO - Step 610700, rl-loss: 131.44030761718754
# INFO - Copied model parameters to target network.
# INFO - Step 610800, rl-loss: 143.88098144531258
# INFO - Copied model parameters to target network.
# INFO - Step 610900, rl-loss: 146.67631530761726
# INFO - Copied model parameters to target network.
# INFO - Step 611000, rl-loss: 419.16397094726565
# INFO - Copied model parameters to target network.
# INFO - Step 611100, rl-loss: 190.52142333984375
# INFO - Copied model parameters to target network.
# INFO - Step 611200, rl-loss: 125.38179016113281
# INFO - Copied model parameters to target network.
# INFO - Step 611300, rl-loss: 221.62231445312588
# INFO - Copied model parameters to target network.
# INFO - Step 611400, rl-loss: 118.87570190429688
# INFO - Copied model parameters to target network.
# INFO - Step 611500, rl-loss: 137.89607238769535
# INFO - Copied model parameters to target network.
# INFO - Step 611600, rl-loss: 388.15853881835944
# INFO - Copied model parameters to target network.
# INFO - Step 611700, rl-loss: 88.937721252441406
# INFO - Copied model parameters to target network.
# INFO - Step 611800, rl-loss: 143.65588378906256
# INFO - Copied model parameters to target network.
# INFO - Step 611900, rl-loss: 400.94750976562512
# INFO - Copied model parameters to target network.
# INFO - Step 612000, rl-loss: 97.662864685058622
# INFO - Copied model parameters to target network.
# INFO - Step 612100, rl-loss: 236.38159179687525
# INFO - Copied model parameters to target network.
# INFO - Step 612200, rl-loss: 456.61026000976565
# INFO - Copied model parameters to target network.
# INFO - Step 612300, rl-loss: 543.15081787109384
# INFO - Copied model parameters to target network.
# INFO - Step 612400, rl-loss: 173.47592163085938
# INFO - Copied model parameters to target network.
# INFO - Step 612500, rl-loss: 314.37750244140625
# INFO - Copied model parameters to target network.
# INFO - Step 612600, rl-loss: 443.21682739257812
# INFO - Copied model parameters to target network.
# INFO - Step 612700, rl-loss: 260.91967773437588
# INFO - Copied model parameters to target network.
# INFO - Step 612800, rl-loss: 187.85105895996094
# INFO - Copied model parameters to target network.
# INFO - Step 612900, rl-loss: 167.57179260253906
# INFO - Copied model parameters to target network.
# INFO - Step 613000, rl-loss: 252.29403686523438
# INFO - Copied model parameters to target network.
# INFO - Step 613100, rl-loss: 176.82141113281255
# INFO - Copied model parameters to target network.
# INFO - Step 613200, rl-loss: 255.15107727050785
# INFO - Copied model parameters to target network.
# INFO - Step 613300, rl-loss: 225.01361083984375
# INFO - Copied model parameters to target network.
# INFO - Step 613400, rl-loss: 110.19658660888672
# INFO - Copied model parameters to target network.
# INFO - Step 613500, rl-loss: 179.43972778320312
# INFO - Copied model parameters to target network.
# INFO - Step 613600, rl-loss: 287.13989257812547
# INFO - Copied model parameters to target network.
# INFO - Step 613700, rl-loss: 139.45080566406252
# INFO - Copied model parameters to target network.
# INFO - Step 613800, rl-loss: 248.30651855468755
# INFO - Copied model parameters to target network.
# INFO - Step 613900, rl-loss: 270.11743164062525
# INFO - Copied model parameters to target network.
# INFO - Step 614000, rl-loss: 205.22363281256251
# INFO - Copied model parameters to target network.
# INFO - Step 614100, rl-loss: 113.56361389160156
# INFO - Copied model parameters to target network.
# INFO - Step 614200, rl-loss: 210.66110229492188
# INFO - Copied model parameters to target network.
# INFO - Step 614300, rl-loss: 113.49513244628906
# INFO - Copied model parameters to target network.
# INFO - Step 614400, rl-loss: 171.00234985351562
# INFO - Copied model parameters to target network.
# INFO - Step 614500, rl-loss: 162.82751464843756
# INFO - Copied model parameters to target network.
# INFO - Step 614600, rl-loss: 112.08889007568365
# INFO - Copied model parameters to target network.
# INFO - Step 614700, rl-loss: 429.79345703125469
# INFO - Copied model parameters to target network.
# INFO - Step 614800, rl-loss: 253.40667724609375
# INFO - Copied model parameters to target network.
# INFO - Step 614900, rl-loss: 150.07363891601562
# INFO - Copied model parameters to target network.
# INFO - Step 615000, rl-loss: 220.40884399414062
# INFO - Copied model parameters to target network.
# INFO - Step 615100, rl-loss: 118.08712768554688
# INFO - Copied model parameters to target network.
# INFO - Step 615200, rl-loss: 134.38632202148438
# INFO - Copied model parameters to target network.
# INFO - Step 615300, rl-loss: 175.75924682617188
# INFO - Copied model parameters to target network.
# INFO - Step 615400, rl-loss: 89.431205749511725
# INFO - Copied model parameters to target network.
# INFO - Step 615500, rl-loss: 483.48193359375975
# INFO - Copied model parameters to target network.
# INFO - Step 615600, rl-loss: 292.52203369140625
# INFO - Copied model parameters to target network.
# INFO - Step 615700, rl-loss: 91.297790527343751
# INFO - Copied model parameters to target network.
# INFO - Step 615800, rl-loss: 132.18247985839844
# INFO - Copied model parameters to target network.
# INFO - Step 615900, rl-loss: 208.75993347167976
# INFO - Copied model parameters to target network.
# INFO - Step 616000, rl-loss: 195.33337402343753
# INFO - Copied model parameters to target network.
# INFO - Step 616100, rl-loss: 71.589050292968755
# INFO - Copied model parameters to target network.
# INFO - Step 616200, rl-loss: 270.29159545898449
# INFO - Copied model parameters to target network.
# INFO - Step 616300, rl-loss: 457.68051147460944
# INFO - Copied model parameters to target network.
# INFO - Step 616400, rl-loss: 208.29873657226562
# INFO - Copied model parameters to target network.
# INFO - Step 616500, rl-loss: 539.76116943359386
# INFO - Copied model parameters to target network.
# INFO - Step 616600, rl-loss: 187.29101562577346
# INFO - Copied model parameters to target network.
# INFO - Step 616700, rl-loss: 145.89884948730476
# INFO - Copied model parameters to target network.
# INFO - Step 616800, rl-loss: 239.77584838867188
# INFO - Copied model parameters to target network.
# INFO - Step 616900, rl-loss: 561.43758862304692
# INFO - Copied model parameters to target network.
# INFO - Step 617000, rl-loss: 213.33317565917972
# INFO - Copied model parameters to target network.
# INFO - Step 617100, rl-loss: 150.54277038574225
# INFO - Copied model parameters to target network.
# INFO - Step 617200, rl-loss: 250.04287719726562
# INFO - Copied model parameters to target network.
# INFO - Step 617300, rl-loss: 391.84915161132818
# INFO - Copied model parameters to target network.
# INFO - Step 617400, rl-loss: 106.83618164062575
# INFO - Copied model parameters to target network.
# INFO - Step 617500, rl-loss: 140.59796142578125
# INFO - Copied model parameters to target network.
# INFO - Step 617600, rl-loss: 250.28210449218759
# INFO - Copied model parameters to target network.
# INFO - Step 617700, rl-loss: 332.15814208984375
# INFO - Copied model parameters to target network.
# INFO - Step 617800, rl-loss: 103.88871765136719
# INFO - Copied model parameters to target network.
# INFO - Step 617900, rl-loss: 257.34063720703125
# INFO - Copied model parameters to target network.
# INFO - Step 618000, rl-loss: 229.47589111328125
# INFO - Copied model parameters to target network.
# INFO - Step 618100, rl-loss: 180.40725708007812
# INFO - Copied model parameters to target network.
# INFO - Step 618200, rl-loss: 68.947372436523445
# INFO - Copied model parameters to target network.
# INFO - Step 618300, rl-loss: 377.71295166015625
# INFO - Copied model parameters to target network.
# INFO - Step 618400, rl-loss: 142.35804748535156
# INFO - Copied model parameters to target network.
# INFO - Step 618500, rl-loss: 241.97004699707032
# INFO - Copied model parameters to target network.
# INFO - Step 618600, rl-loss: 203.00570678710938
# INFO - Copied model parameters to target network.
# INFO - Step 618700, rl-loss: 111.42675781253125
# INFO - Copied model parameters to target network.
# INFO - Step 618800, rl-loss: 266.30621337890625
# INFO - Copied model parameters to target network.
# INFO - Step 618900, rl-loss: 404.56268310546875
# INFO - Copied model parameters to target network.
# INFO - Step 619000, rl-loss: 194.90223693847656
# INFO - Copied model parameters to target network.
# INFO - Step 619100, rl-loss: 209.28909301757812
# INFO - Copied model parameters to target network.
# INFO - Step 619200, rl-loss: 572.82788085937575
# INFO - Copied model parameters to target network.
# INFO - Step 619300, rl-loss: 322.15606689453125
# INFO - Copied model parameters to target network.
# INFO - Step 619400, rl-loss: 292.72933959960942
# INFO - Copied model parameters to target network.
# INFO - Step 619500, rl-loss: 144.60105895996094
# INFO - Copied model parameters to target network.
# INFO - Step 619600, rl-loss: 272.02291870117195
# INFO - Copied model parameters to target network.
# INFO - Step 619700, rl-loss: 88.609138488769535
# INFO - Copied model parameters to target network.
# INFO - Step 619800, rl-loss: 289.83410644531255
# INFO - Copied model parameters to target network.
# INFO - Step 619900, rl-loss: 335.25964355468755
# INFO - Copied model parameters to target network.
# INFO - Step 620000, rl-loss: 110.99378967285156
# INFO - Copied model parameters to target network.
# INFO - Step 620100, rl-loss: 287.20904541015625
# INFO - Copied model parameters to target network.
# INFO - Step 620200, rl-loss: 249.86694335937556
# INFO - Copied model parameters to target network.
# INFO - Step 620300, rl-loss: 331.69357299804698
# INFO - Copied model parameters to target network.
# INFO - Step 620400, rl-loss: 196.93075561523438
# INFO - Copied model parameters to target network.
# INFO - Step 620436, rl-loss: 266.00665283203125
# ----------------------------------------
#   episode      |  2000
#   reward       |  0.0
# ----------------------------------------
# INFO - Step 620500, rl-loss: 376.07354736328125
# INFO - Copied model parameters to target network.
# INFO - Step 620600, rl-loss: 169.91326904296875
# INFO - Copied model parameters to target network.
# INFO - Step 620700, rl-loss: 247.26197814941406
# INFO - Copied model parameters to target network.
# INFO - Step 620800, rl-loss: 377.45730590820314
# INFO - Copied model parameters to target network.
# INFO - Step 620900, rl-loss: 225.22471618652344
# INFO - Copied model parameters to target network.
# INFO - Step 621000, rl-loss: 290.71798706054695
# INFO - Copied model parameters to target network.
# INFO - Step 621100, rl-loss: 374.80654907226561
# INFO - Copied model parameters to target network.
# INFO - Step 621200, rl-loss: 160.78729248046875
# INFO - Copied model parameters to target network.
# INFO - Step 621300, rl-loss: 190.58349609375255
# INFO - Copied model parameters to target network.
# INFO - Step 621400, rl-loss: 368.13787841796875
# INFO - Copied model parameters to target network.
# INFO - Step 621500, rl-loss: 163.62478637695312
# INFO - Copied model parameters to target network.
# INFO - Step 621600, rl-loss: 168.39669799804688
# INFO - Copied model parameters to target network.
# INFO - Step 621700, rl-loss: 191.98393249511728
# INFO - Copied model parameters to target network.
# INFO - Step 621800, rl-loss: 662.02691650390622
# INFO - Copied model parameters to target network.
# INFO - Step 621900, rl-loss: 113.48429870605469
# INFO - Copied model parameters to target network.
# INFO - Step 622000, rl-loss: 292.84020996093755
# INFO - Copied model parameters to target network.
# INFO - Step 622100, rl-loss: 248.09913635253906
# INFO - Copied model parameters to target network.
# INFO - Step 622200, rl-loss: 180.88961791992188
# INFO - Copied model parameters to target network.
# INFO - Step 622300, rl-loss: 298.86953735351565
# INFO - Copied model parameters to target network.
# INFO - Step 622400, rl-loss: 243.48767089843755
# INFO - Copied model parameters to target network.
# INFO - Step 622500, rl-loss: 535.89538574218754
# INFO - Copied model parameters to target network.
# INFO - Step 622600, rl-loss: 190.24545288085938
# INFO - Copied model parameters to target network.
# INFO - Step 622700, rl-loss: 467.27328491210945
# INFO - Copied model parameters to target network.
# INFO - Step 622800, rl-loss: 309.31448364257816
# INFO - Copied model parameters to target network.
# INFO - Step 622900, rl-loss: 129.85351562542198
# INFO - Copied model parameters to target network.
# INFO - Step 623000, rl-loss: 455.16613769531258
# INFO - Copied model parameters to target network.
# INFO - Step 623100, rl-loss: 209.93244934082038
# INFO - Copied model parameters to target network.
# INFO - Step 623200, rl-loss: 475.28848266601565
# INFO - Copied model parameters to target network.
# INFO - Step 623300, rl-loss: 221.78143310546875
# INFO - Copied model parameters to target network.
# INFO - Step 623400, rl-loss: 298.59530639648444
# INFO - Copied model parameters to target network.
# INFO - Step 623500, rl-loss: 278.45907592773448
# INFO - Copied model parameters to target network.
# INFO - Step 623600, rl-loss: 208.32308959960938
# INFO - Copied model parameters to target network.
# INFO - Step 623700, rl-loss: 272.81167602539065
# INFO - Copied model parameters to target network.
# INFO - Step 623800, rl-loss: 280.43981933593754
# INFO - Copied model parameters to target network.
# INFO - Step 623900, rl-loss: 94.247222900390626
# INFO - Copied model parameters to target network.
# INFO - Step 624000, rl-loss: 146.65213012695312
# INFO - Copied model parameters to target network.
# INFO - Step 624100, rl-loss: 424.72830200195315
# INFO - Copied model parameters to target network.
# INFO - Step 624200, rl-loss: 327.64993286132815
# INFO - Copied model parameters to target network.
# INFO - Step 624300, rl-loss: 170.94686889648438
# INFO - Copied model parameters to target network.
# INFO - Step 624400, rl-loss: 132.23040771484375
# INFO - Copied model parameters to target network.
# INFO - Step 624500, rl-loss: 102.24710845947266
# INFO - Copied model parameters to target network.
# INFO - Step 624600, rl-loss: 112.87184143066406
# INFO - Copied model parameters to target network.
# INFO - Step 624700, rl-loss: 165.80892944335938
# INFO - Copied model parameters to target network.
# ...
# INFO - Copied model parameters to target network.
# INFO - Step 1101900, rl-loss: 113.64688110351562
# INFO - Copied model parameters to target network.
# INFO - Step 1102000, rl-loss: 244.93905639648438
# INFO - Copied model parameters to target network.
# INFO - Step 1102100, rl-loss: 197.70364379882812
# INFO - Copied model parameters to target network.
# INFO - Step 1102200, rl-loss: 190.42718505859375
# INFO - Copied model parameters to target network.
# INFO - Step 1102300, rl-loss: 182.00599670410156
# INFO - Copied model parameters to target network.
# INFO - Step 1102400, rl-loss: 171.19680786132812
# INFO - Copied model parameters to target network.
# INFO - Step 1102500, rl-loss: 261.17596435546875
# INFO - Copied model parameters to target network.
# INFO - Step 1102600, rl-loss: 347.64785766601565
# INFO - Copied model parameters to target network.
# INFO - Step 1102700, rl-loss: 298.86810302734375
# INFO - Copied model parameters to target network.
# INFO - Step 1102800, rl-loss: 310.69738769531252
# INFO - Copied model parameters to target network.
# INFO - Step 1102900, rl-loss: 377.68182373046875
# INFO - Copied model parameters to target network.
# INFO - Step 1103000, rl-loss: 246.99145507812544
# INFO - Copied model parameters to target network.
# INFO - Step 1103100, rl-loss: 152.25213623046875
# INFO - Copied model parameters to target network.
# INFO - Step 1103200, rl-loss: 481.84155273437572
# INFO - Copied model parameters to target network.
# INFO - Step 1103300, rl-loss: 408.04150390625752
# INFO - Copied model parameters to target network.
# INFO - Step 1103400, rl-loss: 317.45504760742195
# INFO - Copied model parameters to target network.
# INFO - Step 1103500, rl-loss: 271.57327270507815
# INFO - Copied model parameters to target network.
# INFO - Step 1103600, rl-loss: 203.53553771972656
# INFO - Copied model parameters to target network.
# INFO - Step 1103700, rl-loss: 367.58065795898444
# INFO - Copied model parameters to target network.
# INFO - Step 1103800, rl-loss: 228.91909790039062
# INFO - Copied model parameters to target network.
# INFO - Step 1103900, rl-loss: 189.85647583007812
# INFO - Copied model parameters to target network.
# INFO - Step 1104000, rl-loss: 220.04452514648438
# INFO - Copied model parameters to target network.
# INFO - Step 1104100, rl-loss: 78.629280090332032
# INFO - Copied model parameters to target network.
# INFO - Step 1104200, rl-loss: 87.068283081054695
# INFO - Copied model parameters to target network.
# INFO - Step 1104300, rl-loss: 177.47988891601562
# INFO - Copied model parameters to target network.
# INFO - Step 1104400, rl-loss: 238.71099853515625
# INFO - Copied model parameters to target network.
# INFO - Step 1104500, rl-loss: 144.82777404785156
# INFO - Copied model parameters to target network.
# INFO - Step 1104600, rl-loss: 77.990554809570312
# INFO - Copied model parameters to target network.
# INFO - Step 1104700, rl-loss: 130.24368286132812
# INFO - Copied model parameters to target network.
# INFO - Step 1104800, rl-loss: 64.760101318359385
# INFO - Copied model parameters to target network.
# INFO - Step 1104900, rl-loss: 73.319229125976562
# INFO - Copied model parameters to target network.
# INFO - Step 1105000, rl-loss: 175.24842834472656
# INFO - Copied model parameters to target network.
# INFO - Step 1105100, rl-loss: 477.22872924804698
# INFO - Copied model parameters to target network.
# INFO - Step 1105200, rl-loss: 489.34466552734375
# INFO - Copied model parameters to target network.
# INFO - Step 1105300, rl-loss: 293.09216308593756
# INFO - Copied model parameters to target network.
# INFO - Step 1105400, rl-loss: 55.878810882568368
# INFO - Copied model parameters to target network.
# INFO - Step 1105500, rl-loss: 216.23840332031255
# INFO - Copied model parameters to target network.
# INFO - Step 1105600, rl-loss: 205.33184814453125
# INFO - Copied model parameters to target network.
# INFO - Step 1105700, rl-loss: 410.18829345703125
# INFO - Copied model parameters to target network.
# INFO - Step 1105800, rl-loss: 486.88928222656258
# INFO - Copied model parameters to target network.
# INFO - Step 1105900, rl-loss: 273.05023193359375
# INFO - Copied model parameters to target network.
# INFO - Step 1106000, rl-loss: 439.88442993164064
# INFO - Copied model parameters to target network.
# INFO - Step 1106100, rl-loss: 250.02865600585938
# INFO - Copied model parameters to target network.
# INFO - Step 1106200, rl-loss: 123.81718444824219
# INFO - Copied model parameters to target network.
# INFO - Step 1106300, rl-loss: 389.29791259765625
# INFO - Copied model parameters to target network.
# INFO - Step 1106400, rl-loss: 242.45162963867188
# INFO - Copied model parameters to target network.
# INFO - Step 1106500, rl-loss: 304.55920410156255
# INFO - Copied model parameters to target network.
# INFO - Step 1106600, rl-loss: 217.67759704589844
# INFO - Copied model parameters to target network.
# INFO - Step 1106700, rl-loss: 415.70916748046875
# INFO - Copied model parameters to target network.
# INFO - Step 1106800, rl-loss: 143.48527526855475
# INFO - Copied model parameters to target network.
# INFO - Step 1106900, rl-loss: 73.118095397949222
# INFO - Copied model parameters to target network.
# INFO - Step 1107000, rl-loss: 161.92611694335938
# INFO - Copied model parameters to target network.
# INFO - Step 1107100, rl-loss: 199.06387329101562
# INFO - Copied model parameters to target network.
# INFO - Step 1107200, rl-loss: 257.39196777343755
# INFO - Copied model parameters to target network.
# INFO - Step 1107300, rl-loss: 130.46324157714844
# INFO - Copied model parameters to target network.
# INFO - Step 1107400, rl-loss: 265.13253784179698
# INFO - Copied model parameters to target network.
# INFO - Step 1107500, rl-loss: 221.27404785156252
# INFO - Copied model parameters to target network.
# INFO - Step 1107600, rl-loss: 101.88202667236328
# INFO - Copied model parameters to target network.
# INFO - Step 1107700, rl-loss: 152.59899902343754
# INFO - Copied model parameters to target network.
# INFO - Step 1107800, rl-loss: 246.28710937596875
# INFO - Copied model parameters to target network.
# INFO - Step 1107900, rl-loss: 183.86422729492188
# INFO - Copied model parameters to target network.
# INFO - Step 1108000, rl-loss: 201.52218627929688
# INFO - Copied model parameters to target network.
# INFO - Step 1108100, rl-loss: 623.21490478515625
# INFO - Copied model parameters to target network.
# INFO - Step 1108200, rl-loss: 275.52313232421875
# INFO - Copied model parameters to target network.
# INFO - Step 1108300, rl-loss: 178.83303833007812
# INFO - Copied model parameters to target network.
# INFO - Step 1108400, rl-loss: 173.08831787109375
# INFO - Copied model parameters to target network.
# INFO - Step 1108500, rl-loss: 126.67741394042969
# INFO - Copied model parameters to target network.
# INFO - Step 1108600, rl-loss: 209.15634155273438
# INFO - Copied model parameters to target network.
# INFO - Step 1108700, rl-loss: 134.71382141113284
# INFO - Copied model parameters to target network.
# INFO - Step 1108800, rl-loss: 331.51239013671875
# INFO - Copied model parameters to target network.
# INFO - Step 1108900, rl-loss: 209.75708007812588
# INFO - Copied model parameters to target network.
# INFO - Step 1109000, rl-loss: 159.67764282226562
# INFO - Copied model parameters to target network.
# INFO - Step 1109100, rl-loss: 129.82247924804688
# INFO - Copied model parameters to target network.
# INFO - Step 1109200, rl-loss: 181.04719543457032
# INFO - Copied model parameters to target network.
# INFO - Step 1109300, rl-loss: 442.40881347656258
# INFO - Copied model parameters to target network.
# INFO - Step 1109400, rl-loss: 128.73376464843754
# INFO - Copied model parameters to target network.
# INFO - Step 1109500, rl-loss: 236.79145812988288
# INFO - Copied model parameters to target network.
# INFO - Step 1109600, rl-loss: 232.34706115722656
# INFO - Copied model parameters to target network.
# INFO - Step 1109700, rl-loss: 98.899780273437512
# INFO - Copied model parameters to target network.
# INFO - Step 1109800, rl-loss: 159.03831481933594
# INFO - Copied model parameters to target network.
# INFO - Step 1109900, rl-loss: 236.70712280273438
# INFO - Copied model parameters to target network.
# INFO - Step 1110000, rl-loss: 64.724243164062555
# INFO - Copied model parameters to target network.
# INFO - Step 1110100, rl-loss: 178.54418945312534
# INFO - Copied model parameters to target network.
# INFO - Step 1110200, rl-loss: 105.63175201416016
# INFO - Copied model parameters to target network.
# INFO - Step 1110300, rl-loss: 232.28903198242188
# INFO - Copied model parameters to target network.
# INFO - Step 1110400, rl-loss: 184.37495422363285
# INFO - Copied model parameters to target network.
# INFO - Step 1110500, rl-loss: 124.97019958496094
# INFO - Copied model parameters to target network.
# INFO - Step 1110600, rl-loss: 266.46652221679692
# INFO - Copied model parameters to target network.
# INFO - Step 1110700, rl-loss: 395.63647460937575
# INFO - Copied model parameters to target network.
# INFO - Step 1110800, rl-loss: 248.72338867187556
# INFO - Copied model parameters to target network.
# INFO - Step 1110900, rl-loss: 313.25616455078125
# INFO - Copied model parameters to target network.
# INFO - Step 1111000, rl-loss: 225.37847900390625
# INFO - Copied model parameters to target network.
# INFO - Step 1111100, rl-loss: 271.01049804687538
# INFO - Copied model parameters to target network.
# INFO - Step 1111200, rl-loss: 74.463684082031258
# INFO - Copied model parameters to target network.
# INFO - Step 1111300, rl-loss: 182.91661071777344
# INFO - Copied model parameters to target network.
# INFO - Step 1111400, rl-loss: 178.58520507812598
# INFO - Copied model parameters to target network.
# INFO - Step 1111500, rl-loss: 340.08673095703125
# INFO - Copied model parameters to target network.
# INFO - Step 1111600, rl-loss: 461.78295898437525
# INFO - Copied model parameters to target network.
# INFO - Step 1111700, rl-loss: 253.20108032226562
# INFO - Copied model parameters to target network.
# INFO - Step 1111800, rl-loss: 236.23030090332032
# INFO - Copied model parameters to target network.
# INFO - Step 1111900, rl-loss: 278.30801391601562
# INFO - Copied model parameters to target network.
# INFO - Step 1112000, rl-loss: 425.28988647460945
# INFO - Copied model parameters to target network.
# INFO - Step 1112100, rl-loss: 135.89825439453125
# INFO - Copied model parameters to target network.
# INFO - Step 1112200, rl-loss: 276.75079345703125
# INFO - Copied model parameters to target network.
# INFO - Step 1112300, rl-loss: 104.77007293701172
# INFO - Copied model parameters to target network.
# INFO - Step 1112400, rl-loss: 79.044197082519534
# INFO - Copied model parameters to target network.
# INFO - Step 1112500, rl-loss: 145.04380798339844
# INFO - Copied model parameters to target network.
# INFO - Step 1112600, rl-loss: 155.23278808593756
# INFO - Copied model parameters to target network.
# INFO - Step 1112700, rl-loss: 108.79592895507812
# INFO - Copied model parameters to target network.
# INFO - Step 1112800, rl-loss: 386.12472534179699
# INFO - Copied model parameters to target network.
# INFO - Step 1112900, rl-loss: 75.842063903808625
# INFO - Copied model parameters to target network.
# INFO - Step 1113000, rl-loss: 257.89578247070318
# INFO - Copied model parameters to target network.
# INFO - Step 1113100, rl-loss: 161.49865722656256
# INFO - Copied model parameters to target network.
# INFO - Step 1113200, rl-loss: 82.756256103515625
# INFO - Copied model parameters to target network.
# INFO - Step 1113300, rl-loss: 220.85174560546875
# INFO - Copied model parameters to target network.
# INFO - Step 1113400, rl-loss: 273.88342285156255
# INFO - Copied model parameters to target network.
# INFO - Step 1113500, rl-loss: 74.569992065429692
# INFO - Copied model parameters to target network.
# INFO - Step 1113600, rl-loss: 194.66442871093758
# INFO - Copied model parameters to target network.
# INFO - Step 1113700, rl-loss: 212.48162841796875
# INFO - Copied model parameters to target network.
# INFO - Step 1113800, rl-loss: 304.77758789062578
# INFO - Copied model parameters to target network.
# INFO - Step 1113900, rl-loss: 219.01440429687575
# INFO - Copied model parameters to target network.
# INFO - Step 1114000, rl-loss: 183.46650695800785
# INFO - Copied model parameters to target network.
# INFO - Step 1114100, rl-loss: 237.11245727539062
# INFO - Copied model parameters to target network.
# INFO - Step 1114200, rl-loss: 207.43823242187562
# INFO - Copied model parameters to target network.
# INFO - Step 1114300, rl-loss: 530.13543701171887
# INFO - Copied model parameters to target network.
# INFO - Step 1114400, rl-loss: 81.120300292968752
# INFO - Copied model parameters to target network.
# INFO - Step 1114500, rl-loss: 223.56384277343758
# INFO - Copied model parameters to target network.
# INFO - Step 1114600, rl-loss: 127.24221038818364
# INFO - Copied model parameters to target network.
# INFO - Step 1114700, rl-loss: 124.13941955566406
# INFO - Copied model parameters to target network.
# INFO - Step 1114800, rl-loss: 440.74060058593752
# INFO - Copied model parameters to target network.
# INFO - Step 1114900, rl-loss: 60.438320159912115
# INFO - Copied model parameters to target network.
# INFO - Step 1115000, rl-loss: 160.90734863281255
# INFO - Copied model parameters to target network.
# INFO - Step 1115100, rl-loss: 157.81025695800784
# INFO - Copied model parameters to target network.
# INFO - Step 1115200, rl-loss: 186.93557739257812
# INFO - Copied model parameters to target network.
# INFO - Step 1115300, rl-loss: 61.622718811035156
# INFO - Copied model parameters to target network.
# INFO - Step 1115400, rl-loss: 140.53253173828125
# INFO - Copied model parameters to target network.
# INFO - Step 1115500, rl-loss: 302.67520141601568
# INFO - Copied model parameters to target network.
# INFO - Step 1115600, rl-loss: 129.55616760253906
# INFO - Copied model parameters to target network.
# INFO - Step 1115700, rl-loss: 63.908775329589844
# INFO - Copied model parameters to target network.
# INFO - Step 1115800, rl-loss: 236.36483764648438
# INFO - Copied model parameters to target network.
# INFO - Step 1115900, rl-loss: 299.60235595703125
# INFO - Copied model parameters to target network.
# INFO - Step 1116000, rl-loss: 405.09527587890625
# INFO - Copied model parameters to target network.
# INFO - Step 1116100, rl-loss: 186.80880737304688
# INFO - Copied model parameters to target network.
# INFO - Step 1116200, rl-loss: 188.53509521484375
# INFO - Copied model parameters to target network.
# INFO - Step 1116300, rl-loss: 201.39273071289062
# INFO - Copied model parameters to target network.
# INFO - Step 1116400, rl-loss: 462.57696533203125
# INFO - Copied model parameters to target network.
# INFO - Step 1116500, rl-loss: 334.30761718756719
# INFO - Copied model parameters to target network.
# INFO - Step 1116600, rl-loss: 268.24505615234375
# INFO - Copied model parameters to target network.
# INFO - Step 1116700, rl-loss: 228.18426513671875
# INFO - Copied model parameters to target network.
# INFO - Step 1116800, rl-loss: 288.89398193359375
# INFO - Copied model parameters to target network.
# INFO - Step 1116900, rl-loss: 319.76614379882816
# INFO - Copied model parameters to target network.
# INFO - Step 1117000, rl-loss: 267.97332763671875
# INFO - Copied model parameters to target network.
# INFO - Step 1117100, rl-loss: 501.96545410156254
# INFO - Copied model parameters to target network.
# INFO - Step 1117200, rl-loss: 352.23590087890625
# INFO - Copied model parameters to target network.
# INFO - Step 1117300, rl-loss: 50.097644805908275
# INFO - Copied model parameters to target network.
# INFO - Step 1117400, rl-loss: 196.75497436523438
# INFO - Copied model parameters to target network.
# INFO - Step 1117500, rl-loss: 178.20886230468758
# INFO - Copied model parameters to target network.
# INFO - Step 1117600, rl-loss: 84.877639770507816
# INFO - Copied model parameters to target network.
# INFO - Step 1117700, rl-loss: 218.87971496582032
# INFO - Copied model parameters to target network.
# INFO - Step 1117800, rl-loss: 247.31867980957034
# INFO - Copied model parameters to target network.
# INFO - Step 1117890, rl-loss: 159.85266113281255
# Logs saved in ./experiments/uno_dqn_result/

# %% [markdown]
# ## Evaluating the Agent
# After training, evaluate your agent's performance. You can use RLCard's tournament function to play the game multiple times and see how well your agent performs:

# %%
# Plot the learning curve
plot_curve(csv_path, fig_path, "dqn")

# Save model
save_path = os.path.join(log_dir, 'model.pth')
torch.save(agent, save_path)
print('Model saved in', save_path)
# Out:
# Model saved in ./experiments/uno_dqn_result/model.pth
